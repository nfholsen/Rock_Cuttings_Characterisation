# %% [markdown]
# ### Figures Dataset Notebook

# %%
from cuttings import *

# %%
df_test = pd.read_csv('test/csv_padded_128/test_padded_128_final.csv',index_col=0)

# %%
df_test
# Out:
#                                                   path  \
# 0    ./test/cuttings_padded_128/ML-DB-Geo3_slice003...
# 1    ./test/cuttings_padded_128/ML-DB-Geo3_slice003...
# 2    ./test/cuttings_padded_128/ML-DB-Geo3_slice003...
# 3    ./test/cuttings_padded_128/ML-DB-Geo3_slice003...
# 4    ./test/cuttings_padded_128/ML-DB-Geo3_slice003...
# ..                                                 ...
# 995  ./test/cuttings_padded_128/OL4-3-DL_slice00990...
# 996  ./test/cuttings_padded_128/OL4-3-DL_slice00990...
# 997  ./test/cuttings_padded_128/OL4-3-DL_slice00990...
# 998  ./test/cuttings_padded_128/OL4-3-DL_slice00990...
# 999  ./test/cuttings_padded_128/OL4-3-DL_slice01000...
#
#                    image_name  rock_type   scan_name  label_assigned    area  \
# 0     ML-DB-Geo3_slice00309_3          0  slice00309               3   25868
# 1     ML-DB-Geo3_slice00313_0          0  slice00313               0   11568
# ...

# %%
# The different rock types
classes = np.array(['ML','MS','BL','GN','OL'])

fig, ax = plt.subplots(3,5,figsize=(10,6))

# ML rock type
ax[0,0].imshow(Cuttings(df_test.loc[0,'path'][:24],df_test.loc[0,'path'][24:]).load_picture(),cmap='gray')
ax[0,0].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft='off')
ax[0,0].set_yticklabels([])
ax[0,0].set_title(classes[df_test.loc[0,'rock_type']],fontsize=30)

ax[1,0].imshow(Cuttings(df_test.loc[4,'path'][:24],df_test.loc[4,'path'][24:]).load_picture(),cmap='gray')
ax[1,0].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft='off')
ax[1,0].set_yticklabels([])

ax[2,0].imshow(Cuttings(df_test.loc[160,'path'][:24],df_test.loc[160,'path'][24:]).load_picture(),cmap='gray')
ax[2,0].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft='off')
ax[2,0].set_yticklabels([])

# MS rock type
ax[0,1].imshow(Cuttings(df_test.loc[200,'path'][:24],df_test.loc[200,'path'][24:]).load_picture(),cmap='gray')
ax[0,1].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft='off')
ax[0,1].set_yticklabels([])
ax[0,1].set_title(classes[df_test.loc[200,'rock_type']],fontsize=30)

ax[1,1].imshow(Cuttings(df_test.loc[300,'path'][:24],df_test.loc[300,'path'][24:]).load_picture(),cmap='gray')
ax[1,1].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft='off')
ax[1,1].set_yticklabels([])

ax[2,1].imshow(Cuttings(df_test.loc[377,'path'][:24],df_test.loc[377,'path'][24:]).load_picture(),cmap='gray')
ax[2,1].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft='off')
ax[2,1].set_yticklabels([])

# BL rock type
ax[0,2].imshow(Cuttings(df_test.loc[400,'path'][:24],df_test.loc[400,'path'][24:]).load_picture(),cmap='gray')
ax[0,2].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft='off')
ax[0,2].set_yticklabels([])
ax[0,2].set_title(classes[df_test.loc[400,'rock_type']],fontsize=30)

ax[1,2].imshow(Cuttings(df_test.loc[447,'path'][:24],df_test.loc[447,'path'][24:]).load_picture(),cmap='gray')
ax[1,2].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft='off')
ax[1,2].set_yticklabels([])

ax[2,2].imshow(Cuttings(df_test.loc[532,'path'][:24],df_test.loc[532,'path'][24:]).load_picture(),cmap='gray')
ax[2,2].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft='off')
ax[2,2].set_yticklabels([])

# GN rock type
ax[0,3].imshow(Cuttings(df_test.loc[615,'path'][:24],df_test.loc[615,'path'][24:]).load_picture(),cmap='gray')
ax[0,3].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft='off')
ax[0,3].set_yticklabels([])
ax[0,3].set_title(classes[df_test.loc[615,'rock_type']],fontsize=30)

ax[1,3].imshow(Cuttings(df_test.loc[650,'path'][:24],df_test.loc[650,'path'][24:]).load_picture(),cmap='gray')
ax[1,3].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft='off')
ax[1,3].set_yticklabels([])

ax[2,3].imshow(Cuttings(df_test.loc[745,'path'][:24],df_test.loc[745,'path'][24:]).load_picture(),cmap='gray')
ax[2,3].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft='off')
ax[2,3].set_yticklabels([])

# OL rock type
ax[0,4].imshow(Cuttings(df_test.loc[800,'path'][:24],df_test.loc[800,'path'][24:]).load_picture(),cmap='gray')
ax[0,4].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft='off')
ax[0,4].set_yticklabels([])
ax[0,4].set_title(classes[df_test.loc[800,'rock_type']],fontsize=30)

ax[1,4].imshow(Cuttings(df_test.loc[830,'path'][:24],df_test.loc[830,'path'][24:]).load_picture(),cmap='gray')
ax[1,4].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft='off')
ax[1,4].set_yticklabels([])

ax[2,4].imshow(Cuttings(df_test.loc[900,'path'][:24],df_test.loc[900,'path'][24:]).load_picture(),cmap='gray')
ax[2,4].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft='off')
ax[2,4].set_yticklabels([])

# Save figure
plt.tight_layout()
plt.savefig('rock_type_problem_name_new.png',bbox_inches='tight')

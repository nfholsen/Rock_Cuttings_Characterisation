# %%
from cuttings import *

import torch
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import time
import copy
import PIL.Image as Image
import random

import torch.optim as optim
import torchvision.transforms as tf
from torch.utils import data 
import torch.nn as nn
import torch.nn.functional as F

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

import pickle

# %%
# torchvision for pre-trained models
from torchvision import models

# %% [markdown]
# #### Classes

# %%
class MinMaxNormalization(object):
    """
    Normalized (Min-Max) the image.
    """
    def __init__(self, vmin=0, vmax=1):
        """
        Constructor of the grayscale transform.
        ----------
        INPUT
            |---- vmin (float / int) the desired minimum value.
            |---- vmax (float / int) the desired maximum value.
        OUTPUT
            |---- None
        """
        self.vmin = vmin
        self.vmax = vmax

    def __call__(self, image, mask=None):
        """
        Apply a Min-Max Normalization to the image.
        ----------
        INPUT
            |---- image (PIL.Image) the image to normalize.
        OUTPUT
            |---- image (np.array) the normalized image.
        """
        arr = np.array(image).astype('float32')
        arr = (arr - arr.min()) / (arr.max() - arr.min())
        arr = (self.vmax - self.vmin) * arr + self.vmin
        return arr

# %%
class Cuttings_Dataset(data.Dataset):
    def __init__(self, sample_df, data_path, mean, std, resize,data_augmentation=True):
        """
        Constructor of the dataset.
        """
        data.Dataset.__init__(self)
        self.sample_df = sample_df
        self.data_path = data_path
        self.data_augmentation = data_augmentation
        
        self.transform =  tf.Compose([tf.Grayscale(num_output_channels=3),
                                        MinMaxNormalization(),
                                        tf.ToTensor(),
                                        tf.Normalize((mean,mean,mean),(std,std,std))])
        
        if data_augmentation:
            self.transform = tf.Compose([tf.Grayscale(num_output_channels=3),
                                            tf.RandomVerticalFlip(p=0.5),
                                            tf.RandomHorizontalFlip(p=0.5),
                                            tf.RandomRotation([-90,90],resample=False, expand=False, center=None, fill=None),
                                            MinMaxNormalization(),
                                            tf.ToTensor(),
                                            tf.Normalize((mean,mean,mean),(std,std,std))])
        
        if resize:
            self.transform = tf.Compose([tf.Grayscale(num_output_channels=3),
                                            tf.Resize(224),
                                            tf.RandomVerticalFlip(p=0.5),
                                            tf.RandomHorizontalFlip(p=0.5),
                                            tf.RandomRotation([-90,90],resample=False, expand=False, center=None, fill=None),
                                            MinMaxNormalization(),
                                            tf.ToTensor(),
                                            tf.Normalize((mean,mean,mean),(std,std,std))])
    def __len__(self):
        """
        Get the number of samples in the dataset.
        """
        return self.sample_df.shape[0]


    def __getitem__(self, idx):
        """
        Get an item from the dataset.
        """
        # load image
        im = Image.open(self.data_path + self.sample_df.loc[idx,'path'])
        # load label
        label = torch.tensor(self.sample_df.loc[idx,'rock_type'])
        
        im = self.transform(im)
        return im,label

# %% [markdown]
# #### Loading data

# %%
classes = np.array(['ML', 'MS','BL','GN','OL'])

date = '05_05_20'

df = pd.read_csv('train/csv_'+date+'/train'+date+'_final.csv',index_col=0)

train,val = train_test_split(df,test_size=0.2,random_state=0,stratify=df['rock_type'])
cuttings_datasets = {}

cuttings_datasets['train'] = Cuttings_Dataset(train.reset_index(drop=True),'',data_augmentation=True)
cuttings_datasets['val'] = Cuttings_Dataset(val.reset_index(drop=True),'',data_augmentation=False)
cuttings_datasets['test'] = Cuttings_Dataset(pd.read_csv('test'+'/csv_'+date+'/'+'test'+date+'_final.csv',index_col=0),'',data_augmentation=False)

dataloaders = {x: torch.utils.data.DataLoader(cuttings_datasets[x], batch_size=16,
                                             shuffle=True, num_workers=0)
              for x in ['train', 'val', 'test']}

dataset_sizes = {x: len(cuttings_datasets[x]) for x in ['train','val','test']}

# %%
# Flag for feature extracting. When False, we finetune the whole model,
# when True we only update the reshaped layer params

# %%
def initialize_model(num_classes, feature_extract=True, use_pretrained=True):
    
    # By default, when we load a pretrained model all of the parameters have .requires_grad=True
    model_ft = models.resnet18(pretrained=use_pretrained)
    num_ftrs = model_ft.fc.in_features
    model_ft.fc = nn.Linear(num_ftrs, num_classes)
    return model_ft

# %%
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %%
model_ft = initialize_model(len(classes))

# %%
for name,param in model_ft.named_parameters():
    if param.requires_grad == True:
        print("\t",name)
# Out:
# 	 conv1.weight
# 	 bn1.weight
# 	 bn1.bias
# 	 layer1.0.conv1.weight
# 	 layer1.0.bn1.weight
# 	 layer1.0.bn1.bias
# 	 layer1.0.conv2.weight
# 	 layer1.0.bn2.weight
# 	 layer1.0.bn2.bias
# 	 layer1.1.conv1.weight
# 	 layer1.1.bn1.weight
# 	 layer1.1.bn1.bias
# 	 layer1.1.conv2.weight
# 	 layer1.1.bn2.weight
# 	 layer1.1.bn2.bias
# 	 layer2.0.conv1.weight
# 	 layer2.0.bn1.weight
# 	 layer2.0.bn1.bias
# 	 layer2.0.conv2.weight
# 	 layer2.0.bn2.weight
# 	 layer2.0.bn2.bias
# 	 layer2.0.downsample.0.weight
# 	 layer2.0.downsample.1.weight
# 	 layer2.0.downsample.1.bias
# 	 layer2.1.conv1.weight
# 	 layer2.1.bn1.weight
# 	 layer2.1.bn1.bias
# 	 layer2.1.conv2.weight
# 	 layer2.1.bn2.weight
# 	 layer2.1.bn2.bias
# 	 layer3.0.conv1.weight
# 	 layer3.0.bn1.weight
# 	 layer3.0.bn1.bias
# 	 layer3.0.conv2.weight
# 	 layer3.0.bn2.weight
# 	 layer3.0.bn2.bias
# 	 layer3.0.downsample.0.weight
# 	 layer3.0.downsample.1.weight
# 	 layer3.0.downsample.1.bias
# 	 layer3.1.conv1.weight
# 	 layer3.1.bn1.weight
# 	 layer3.1.bn1.bias
# 	 layer3.1.conv2.weight
# 	 layer3.1.bn2.weight
# 	 layer3.1.bn2.bias
# 	 layer4.0.conv1.weight
# 	 layer4.0.bn1.weight
# 	 layer4.0.bn1.bias
# 	 layer4.0.conv2.weight
# 	 layer4.0.bn2.weight
# 	 layer4.0.bn2.bias
# 	 layer4.0.downsample.0.weight
# 	 layer4.0.downsample.1.weight
# 	 layer4.0.downsample.1.bias
# 	 layer4.1.conv1.weight
# 	 layer4.1.bn1.weight
# 	 layer4.1.bn1.bias
# 	 layer4.1.conv2.weight
# 	 layer4.1.bn2.weight
# 	 layer4.1.bn2.bias
# 	 fc.weight
# 	 fc.bias

# %%
def train_model(model, criterion, optimizer, num_epochs=25):
    since = time.time()
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    
    loss_train = []
    acc_train = []
    loss_val = []
    acc_val = []
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        running_loss_train = 0.0
        running_corrects_train = 0
            
        model.train()# Set model to training mode
        
        # Iterate over data Training
        for inputs, labels in dataloaders['train']:
            inputs = inputs.to(device)
            inputs.require_grad = True
            labels = labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward
            outputs = model(inputs)
            preds = torch.argmax(outputs, 1)
            loss = criterion(outputs, labels)

            # backward + optimize
            loss.backward()
            optimizer.step()

            # statistics
            running_loss_train += loss.item() * inputs.size(0)
            running_corrects_train += torch.sum(preds == labels.data)
            
        epoch_loss_train = running_loss_train / dataset_sizes["train"]
        epoch_acc_train = running_corrects_train.double() / dataset_sizes["train"]
        loss_train.append(epoch_loss_train)
        acc_train.append(epoch_acc_train)
        
        print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                "Train", epoch_loss_train, epoch_acc_train))
        
        running_loss_val = 0.0
        running_corrects_val = 0
            
        model.eval() # Set model to evaluate mode
        
        # Iterate over data Evaluation
        for inputs, labels in dataloaders["val"]:
            inputs = inputs.to(device)
            labels = labels.to(device)
                
            with torch.no_grad():
                # forward
                outputs = model(inputs)
                preds = torch.argmax(outputs, 1)
                loss = criterion(outputs, labels)   

            # statistics
            running_loss_val += loss.item() * inputs.size(0)
            running_corrects_val += torch.sum(preds == labels.data)

        epoch_loss_val = running_loss_val / dataset_sizes["val"]
        epoch_acc_val = running_corrects_val.double() / dataset_sizes["val"]
        loss_val.append(epoch_loss_val)
        acc_val.append(epoch_acc_val)
        
        print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                "Val", epoch_loss_val, epoch_acc_val))
            
        # deep copy the model
        if epoch_acc_val > best_acc:
            best_acc = epoch_acc_val
            best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, loss_train, acc_train, loss_val, acc_val

# %%
# prediciton
def prediciton(model):
    preds_vec = []
    true_vec = []
    
    model.eval()
    with torch.no_grad():
        for inputs, labels in dataloaders['test']:
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            
            preds_vec+=preds.tolist()
            true_vec+=labels.tolist()
    return preds_vec, true_vec

# %%
# Get Cuda
date= '13_06_20'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Train Model
list_loss_train = []
list_acc_train = []
list_loss_val = []
list_acc_val = []
list_preds_vec = []
list_true_vec = []

for i in range(3):
    model_ft = initialize_model(len(classes))

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model_ft.parameters())

    model_ft = model_ft.to(device)

    model_ft, loss_train, acc_train, loss_val, acc_val = train_model(model_ft, criterion, optimizer,
                       num_epochs=200)
    
    preds_vec, true_vec = prediciton(model_ft)
    
    list_loss_train.append(loss_train)
    list_acc_train.append(acc_train)
    list_loss_val.append(loss_val)
    list_acc_val.append(acc_val)
    list_preds_vec.append(preds_vec)
    list_true_vec.append(true_vec)
    
    torch.save(model_ft, f'results/Resnet18_{i}_{date}')
# Save Pickles
results = open(f'results/Resnet18_results_{date}', 'wb')
pickle.dump([[list_loss_train],[list_acc_train],[list_loss_val],[list_acc_val],[list_preds_vec],[list_true_vec]],results)
results.close()
# Out:
# cuda:0
# Epoch 0/199
# ----------
# Train Loss: 0.7563 Acc: 0.7275
# Val Loss: 0.5986 Acc: 0.7920
#
# Epoch 1/199
# ----------
# Train Loss: 0.5785 Acc: 0.7900
# Val Loss: 1.3576 Acc: 0.6170
#
# Epoch 2/199
# ----------
# Train Loss: 0.5094 Acc: 0.8230
# Val Loss: 0.3969 Acc: 0.8500
#
# Epoch 3/199
# ----------
# Train Loss: 0.4280 Acc: 0.8473
# Val Loss: 0.4606 Acc: 0.8240
#
# Epoch 4/199
# ----------
# Train Loss: 0.3735 Acc: 0.8700
# Val Loss: 0.4108 Acc: 0.8530
#
# Epoch 5/199
# ----------
# Train Loss: 0.3902 Acc: 0.8593
# Val Loss: 0.3459 Acc: 0.8890
#
# Epoch 6/199
# ----------
# Train Loss: 0.3430 Acc: 0.8668
# Val Loss: 0.3694 Acc: 0.8490
#
# Epoch 7/199
# ----------
# Train Loss: 0.3452 Acc: 0.8688
# Val Loss: 0.3377 Acc: 0.8650
#
# Epoch 8/199
# ----------
# Train Loss: 0.3396 Acc: 0.8765
# Val Loss: 0.2780 Acc: 0.8850
#
# Epoch 9/199
# ----------
# Train Loss: 0.3022 Acc: 0.8912
# Val Loss: 0.2681 Acc: 0.9000
#
# Epoch 10/199
# ----------
# Train Loss: 0.2866 Acc: 0.8972
# Val Loss: 0.2672 Acc: 0.8920
#
# Epoch 11/199
# ----------
# Train Loss: 0.2960 Acc: 0.8960
# Val Loss: 0.2772 Acc: 0.8890
#
# Epoch 12/199
# ----------
# Train Loss: 0.2497 Acc: 0.9060
# Val Loss: 0.3265 Acc: 0.8750
#
# Epoch 13/199
# ----------
# Train Loss: 0.2626 Acc: 0.9020
# Val Loss: 0.3895 Acc: 0.8350
#
# Epoch 14/199
# ----------
# Train Loss: 0.2648 Acc: 0.9055
# Val Loss: 0.2728 Acc: 0.8780
#
# Epoch 15/199
# ----------
# Train Loss: 0.2333 Acc: 0.9155
# Val Loss: 0.2074 Acc: 0.9210
#
# Epoch 16/199
# ----------
# Train Loss: 0.2507 Acc: 0.9080
# Val Loss: 0.2193 Acc: 0.9070
#
# Epoch 17/199
# ----------
# Train Loss: 0.2467 Acc: 0.9108
# Val Loss: 0.3086 Acc: 0.9000
#
# Epoch 18/199
# ----------
# Train Loss: 0.2509 Acc: 0.9085
# Val Loss: 0.2085 Acc: 0.9210
#
# Epoch 19/199
# ----------
# Train Loss: 0.2156 Acc: 0.9223
# Val Loss: 0.2480 Acc: 0.9000
#
# Epoch 20/199
# ----------
# Train Loss: 0.2220 Acc: 0.9185
# Val Loss: 0.2161 Acc: 0.9110
#
# Epoch 21/199
# ----------
# Train Loss: 0.2189 Acc: 0.9190
# Val Loss: 0.9520 Acc: 0.7650
#
# Epoch 22/199
# ----------
# Train Loss: 0.2356 Acc: 0.9158
# Val Loss: 0.1913 Acc: 0.9280
#
# Epoch 23/199
# ----------
# Train Loss: 0.2169 Acc: 0.9220
# Val Loss: 0.2449 Acc: 0.8840
#
# Epoch 24/199
# ----------
# Train Loss: 0.1988 Acc: 0.9287
# Val Loss: 0.1655 Acc: 0.9430
#
# Epoch 25/199
# ----------
# Train Loss: 0.2052 Acc: 0.9233
# Val Loss: 0.2602 Acc: 0.9040
#
# Epoch 26/199
# ----------
# Train Loss: 0.1929 Acc: 0.9283
# Val Loss: 0.2009 Acc: 0.9260
#
# Epoch 27/199
# ----------
# Train Loss: 0.1685 Acc: 0.9370
# Val Loss: 0.2709 Acc: 0.8920
#
# Epoch 28/199
# ----------
# Train Loss: 0.1915 Acc: 0.9280
# Val Loss: 0.1890 Acc: 0.9290
#
# Epoch 29/199
# ----------
# Train Loss: 0.1914 Acc: 0.9293
# Val Loss: 0.1990 Acc: 0.9170
#
# Epoch 30/199
# ----------
# Train Loss: 0.1819 Acc: 0.9373
# Val Loss: 0.2397 Acc: 0.9230
#
# Epoch 31/199
# ----------
# Train Loss: 0.1580 Acc: 0.9403
# Val Loss: 0.2382 Acc: 0.9110
#
# Epoch 32/199
# ----------
# Train Loss: 0.1676 Acc: 0.9427
# Val Loss: 0.1693 Acc: 0.9360
#
# Epoch 33/199
# ----------
# Train Loss: 0.1532 Acc: 0.9443
# Val Loss: 0.1619 Acc: 0.9390
#
# Epoch 34/199
# ----------
# Train Loss: 0.1716 Acc: 0.9405
# Val Loss: 0.3414 Acc: 0.8740
#
# Epoch 35/199
# ----------
# Train Loss: 0.1672 Acc: 0.9370
# Val Loss: 0.1630 Acc: 0.9370
#
# Epoch 36/199
# ----------
# Train Loss: 0.1617 Acc: 0.9420
# Val Loss: 0.2288 Acc: 0.9170
#
# Epoch 37/199
# ----------
# Train Loss: 0.1496 Acc: 0.9443
# Val Loss: 0.2503 Acc: 0.8970
#
# Epoch 38/199
# ----------
# Train Loss: 0.1857 Acc: 0.9337
# Val Loss: 0.2035 Acc: 0.9230
#
# Epoch 39/199
# ----------
# Train Loss: 0.1707 Acc: 0.9367
# Val Loss: 0.1858 Acc: 0.9280
#
# Epoch 40/199
# ----------
# Train Loss: 0.1587 Acc: 0.9415
# Val Loss: 0.3203 Acc: 0.9050
#
# Epoch 41/199
# ----------
# Train Loss: 0.1402 Acc: 0.9443
# Val Loss: 0.1506 Acc: 0.9390
#
# Epoch 42/199
# ----------
# Train Loss: 0.1400 Acc: 0.9503
# Val Loss: 0.1776 Acc: 0.9350
#
# Epoch 43/199
# ----------
# Train Loss: 0.1494 Acc: 0.9470
# Val Loss: 0.2744 Acc: 0.9070
#
# Epoch 44/199
# ----------
# Train Loss: 0.1458 Acc: 0.9453
# Val Loss: 0.3370 Acc: 0.8700
#
# Epoch 45/199
# ----------
# Train Loss: 0.1319 Acc: 0.9505
# Val Loss: 0.1772 Acc: 0.9370
#
# Epoch 46/199
# ----------
# Train Loss: 0.1244 Acc: 0.9540
# Val Loss: 0.1731 Acc: 0.9280
#
# Epoch 47/199
# ----------
# Train Loss: 0.1350 Acc: 0.9497
# Val Loss: 0.1623 Acc: 0.9320
#
# Epoch 48/199
# ----------
# Train Loss: 0.1315 Acc: 0.9470
# Val Loss: 0.2295 Acc: 0.9050
#
# Epoch 49/199
# ----------
# Train Loss: 0.1161 Acc: 0.9557
# Val Loss: 0.2266 Acc: 0.9230
#
# Epoch 50/199
# ----------
# Train Loss: 0.1145 Acc: 0.9567
# Val Loss: 0.1711 Acc: 0.9320
#
# Epoch 51/199
# ----------
# Train Loss: 0.1262 Acc: 0.9570
# Val Loss: 0.1435 Acc: 0.9520
#
# Epoch 52/199
# ----------
# Train Loss: 0.1539 Acc: 0.9413
# Val Loss: 0.1973 Acc: 0.9250
#
# Epoch 53/199
# ----------
# Train Loss: 0.1189 Acc: 0.9513
# Val Loss: 0.1769 Acc: 0.9420
#
# Epoch 54/199
# ----------
# Train Loss: 0.1329 Acc: 0.9530
# Val Loss: 0.1810 Acc: 0.9310
#
# Epoch 55/199
# ----------
# Train Loss: 0.1017 Acc: 0.9617
# Val Loss: 0.2374 Acc: 0.9160
#
# Epoch 56/199
# ----------
# Train Loss: 0.1203 Acc: 0.9553
# Val Loss: 0.2253 Acc: 0.9140
#
# Epoch 57/199
# ----------
# Train Loss: 0.1392 Acc: 0.9490
# Val Loss: 0.1519 Acc: 0.9350
#
# Epoch 58/199
# ----------
# Train Loss: 0.1137 Acc: 0.9577
# Val Loss: 0.1645 Acc: 0.9350
#
# Epoch 59/199
# ----------
# Train Loss: 0.1192 Acc: 0.9580
# Val Loss: 0.2804 Acc: 0.9100
#
# Epoch 60/199
# ----------
# Train Loss: 0.0954 Acc: 0.9645
# Val Loss: 0.1856 Acc: 0.9390
#
# Epoch 61/199
# ----------
# Train Loss: 0.1374 Acc: 0.9523
# Val Loss: 0.1690 Acc: 0.9350
#
# Epoch 62/199
# ----------
# Train Loss: 0.0977 Acc: 0.9623
# Val Loss: 0.1865 Acc: 0.9350
#
# Epoch 63/199
# ----------
# Train Loss: 0.1237 Acc: 0.9563
# Val Loss: 0.1385 Acc: 0.9440
#
# Epoch 64/199
# ----------
# Train Loss: 0.1116 Acc: 0.9583
# Val Loss: 0.1495 Acc: 0.9480
#
# Epoch 65/199
# ----------
# Train Loss: 0.0994 Acc: 0.9605
# Val Loss: 0.1304 Acc: 0.9500
#
# Epoch 66/199
# ----------
# Train Loss: 0.0903 Acc: 0.9635
# Val Loss: 0.1276 Acc: 0.9530
#
# Epoch 67/199
# ----------
# Train Loss: 0.1236 Acc: 0.9567
# Val Loss: 0.8370 Acc: 0.7320
#
# Epoch 68/199
# ----------
# Train Loss: 0.0990 Acc: 0.9593
# Val Loss: 0.1521 Acc: 0.9450
#
# Epoch 69/199
# ----------
# Train Loss: 0.0923 Acc: 0.9640
# Val Loss: 0.1638 Acc: 0.9350
#
# Epoch 70/199
# ----------
# Train Loss: 0.0939 Acc: 0.9623
# Val Loss: 0.1428 Acc: 0.9500
#
# Epoch 71/199
# ----------
# Train Loss: 0.0962 Acc: 0.9653
# Val Loss: 0.1457 Acc: 0.9530
#
# Epoch 72/199
# ----------
# Train Loss: 0.0963 Acc: 0.9663
# Val Loss: 0.2173 Acc: 0.9160
#
# Epoch 73/199
# ----------
# Train Loss: 0.1010 Acc: 0.9627
# Val Loss: 0.1479 Acc: 0.9510
#
# Epoch 74/199
# ----------
# Train Loss: 0.1156 Acc: 0.9603
# Val Loss: 0.1625 Acc: 0.9420
#
# Epoch 75/199
# ----------
# Train Loss: 0.1199 Acc: 0.9575
# Val Loss: 0.5888 Acc: 0.8490
#
# Epoch 76/199
# ----------
# Train Loss: 0.0867 Acc: 0.9667
# Val Loss: 0.1689 Acc: 0.9480
#
# Epoch 77/199
# ----------
# Train Loss: 0.0807 Acc: 0.9723
# Val Loss: 0.1315 Acc: 0.9490
#
# Epoch 78/199
# ----------
# Train Loss: 0.1012 Acc: 0.9615
# Val Loss: 0.1855 Acc: 0.9380
#
# Epoch 79/199
# ----------
# Train Loss: 0.0870 Acc: 0.9673
# Val Loss: 0.1435 Acc: 0.9520
#
# Epoch 80/199
# ----------
# Train Loss: 0.0990 Acc: 0.9653
# Val Loss: 0.2069 Acc: 0.9200
#
# Epoch 81/199
# ----------
# Train Loss: 0.1051 Acc: 0.9647
# Val Loss: 0.1792 Acc: 0.9320
#
# Epoch 82/199
# ----------
# Train Loss: 0.0755 Acc: 0.9730
# Val Loss: 0.1661 Acc: 0.9400
#
# Epoch 83/199
# ----------
# Train Loss: 0.0962 Acc: 0.9660
# Val Loss: 0.1333 Acc: 0.9490
#
# Epoch 84/199
# ----------
# Train Loss: 0.0717 Acc: 0.9728
# Val Loss: 0.1631 Acc: 0.9550
#
# Epoch 85/199
# ----------
# Train Loss: 0.1000 Acc: 0.9620
# Val Loss: 0.1790 Acc: 0.9390
#
# Epoch 86/199
# ----------
# Train Loss: 0.0946 Acc: 0.9627
# Val Loss: 0.1480 Acc: 0.9520
#
# Epoch 87/199
# ----------
# Train Loss: 0.0866 Acc: 0.9703
# Val Loss: 0.1748 Acc: 0.9310
#
# Epoch 88/199
# ----------
# Train Loss: 0.0915 Acc: 0.9693
# Val Loss: 0.3767 Acc: 0.8920
#
# Epoch 89/199
# ----------
# Train Loss: 0.0867 Acc: 0.9695
# Val Loss: 0.1721 Acc: 0.9380
#
# Epoch 90/199
# ----------
# Train Loss: 0.0831 Acc: 0.9657
# Val Loss: 0.1407 Acc: 0.9450
#
# Epoch 91/199
# ----------
# Train Loss: 0.0740 Acc: 0.9710
# Val Loss: 0.2755 Acc: 0.9090
#
# Epoch 92/199
# ----------
# Train Loss: 0.0874 Acc: 0.9675
# Val Loss: 0.3605 Acc: 0.8810
#
# Epoch 93/199
# ----------
# Train Loss: 0.1037 Acc: 0.9633
# Val Loss: 0.1320 Acc: 0.9580
#
# Epoch 94/199
# ----------
# Train Loss: 0.0919 Acc: 0.9708
# Val Loss: 0.1337 Acc: 0.9590
#
# Epoch 95/199
# ----------
# Train Loss: 0.0712 Acc: 0.9753
# Val Loss: 0.4230 Acc: 0.8740
#
# Epoch 96/199
# ----------
# Train Loss: 0.0706 Acc: 0.9725
# Val Loss: 0.1679 Acc: 0.9490
#
# Epoch 97/199
# ----------
# Train Loss: 0.0819 Acc: 0.9688
# Val Loss: 0.2151 Acc: 0.9300
#
# Epoch 98/199
# ----------
# Train Loss: 0.0796 Acc: 0.9725
# Val Loss: 0.1820 Acc: 0.9310
#
# Epoch 99/199
# ----------
# Train Loss: 0.0754 Acc: 0.9713
# Val Loss: 0.1540 Acc: 0.9540
#
# Epoch 100/199
# ----------
# Train Loss: 0.0681 Acc: 0.9753
# Val Loss: 0.2046 Acc: 0.9330
#
# Epoch 101/199
# ----------
# Train Loss: 0.0677 Acc: 0.9735
# Val Loss: 0.1245 Acc: 0.9570
#
# Epoch 102/199
# ----------
# Train Loss: 0.0552 Acc: 0.9800
# Val Loss: 0.1814 Acc: 0.9470
#
# Epoch 103/199
# ----------
# Train Loss: 0.0822 Acc: 0.9713
# Val Loss: 0.1577 Acc: 0.9440
#
# Epoch 104/199
# ----------
# Train Loss: 0.0967 Acc: 0.9690
# Val Loss: 0.1348 Acc: 0.9490
#
# Epoch 105/199
# ----------
# Train Loss: 0.0799 Acc: 0.9718
# Val Loss: 0.1962 Acc: 0.9210
#
# Epoch 106/199
# ----------
# Train Loss: 0.0942 Acc: 0.9710
# Val Loss: 0.1704 Acc: 0.9400
#
# Epoch 107/199
# ----------
# Train Loss: 0.0750 Acc: 0.9748
# Val Loss: 0.1287 Acc: 0.9440
#
# Epoch 108/199
# ----------
# Train Loss: 0.0616 Acc: 0.9728
# Val Loss: 0.1303 Acc: 0.9530
#
# Epoch 109/199
# ----------
# Train Loss: 0.0679 Acc: 0.9735
# Val Loss: 0.1177 Acc: 0.9580
#
# Epoch 110/199
# ----------
# Train Loss: 0.0445 Acc: 0.9835
# Val Loss: 0.1722 Acc: 0.9440
#
# Epoch 111/199
# ----------
# Train Loss: 0.0709 Acc: 0.9758
# Val Loss: 0.1509 Acc: 0.9470
#
# Epoch 112/199
# ----------
# Train Loss: 0.0657 Acc: 0.9775
# Val Loss: 0.1717 Acc: 0.9450
#
# Epoch 113/199
# ----------
# Train Loss: 0.0543 Acc: 0.9808
# Val Loss: 0.1776 Acc: 0.9460
#
# Epoch 114/199
# ----------
# Train Loss: 0.0505 Acc: 0.9820
# Val Loss: 0.1629 Acc: 0.9500
#
# Epoch 115/199
# ----------
# Train Loss: 0.0607 Acc: 0.9770
# Val Loss: 0.1885 Acc: 0.9400
#
# Epoch 116/199
# ----------
# Train Loss: 0.0561 Acc: 0.9825
# Val Loss: 0.1673 Acc: 0.9490
#
# Epoch 117/199
# ----------
# Train Loss: 0.0710 Acc: 0.9743
# Val Loss: 0.1828 Acc: 0.9450
#
# Epoch 118/199
# ----------
# Train Loss: 0.0563 Acc: 0.9795
# Val Loss: 0.1947 Acc: 0.9540
#
# Epoch 119/199
# ----------
# Train Loss: 0.0616 Acc: 0.9798
# Val Loss: 0.2155 Acc: 0.9360
#
# Epoch 120/199
# ----------
# Train Loss: 0.0849 Acc: 0.9718
# Val Loss: 0.1374 Acc: 0.9470
#
# Epoch 121/199
# ----------
# Train Loss: 0.0700 Acc: 0.9760
# Val Loss: 0.1415 Acc: 0.9530
#
# Epoch 122/199
# ----------
# Train Loss: 0.0525 Acc: 0.9820
# Val Loss: 0.1439 Acc: 0.9470
#
# Epoch 123/199
# ----------
# Train Loss: 0.0683 Acc: 0.9753
# Val Loss: 0.1460 Acc: 0.9570
#
# Epoch 124/199
# ----------
# Train Loss: 0.0587 Acc: 0.9783
# Val Loss: 0.1796 Acc: 0.9400
#
# Epoch 125/199
# ----------
# Train Loss: 0.0421 Acc: 0.9858
# Val Loss: 0.1928 Acc: 0.9420
#
# Epoch 126/199
# ----------
# Train Loss: 0.0589 Acc: 0.9800
# Val Loss: 0.1371 Acc: 0.9610
#
# Epoch 127/199
# ----------
# Train Loss: 0.0412 Acc: 0.9850
# Val Loss: 0.1506 Acc: 0.9460
#
# Epoch 128/199
# ----------
# Train Loss: 0.0636 Acc: 0.9788
# Val Loss: 0.1812 Acc: 0.9460
#
# Epoch 129/199
# ----------
# Train Loss: 0.0561 Acc: 0.9818
# Val Loss: 0.1558 Acc: 0.9450
#
# Epoch 130/199
# ----------
# Train Loss: 0.0525 Acc: 0.9810
# Val Loss: 0.1795 Acc: 0.9500
#
# Epoch 131/199
# ----------
# Train Loss: 0.0539 Acc: 0.9803
# Val Loss: 0.1791 Acc: 0.9570
#
# Epoch 132/199
# ----------
# Train Loss: 0.0619 Acc: 0.9798
# Val Loss: 0.1588 Acc: 0.9480
#
# Epoch 133/199
# ----------
# Train Loss: 0.0651 Acc: 0.9778
# Val Loss: 0.1430 Acc: 0.9510
#
# Epoch 134/199
# ----------
# Train Loss: 0.0524 Acc: 0.9793
# Val Loss: 0.1542 Acc: 0.9530
#
# Epoch 135/199
# ----------
# Train Loss: 0.0521 Acc: 0.9820
# Val Loss: 0.1420 Acc: 0.9580
#
# Epoch 136/199
# ----------
# Train Loss: 0.0404 Acc: 0.9848
# Val Loss: 0.2653 Acc: 0.9280
#
# Epoch 137/199
# ----------
# Train Loss: 0.0643 Acc: 0.9755
# Val Loss: 0.1502 Acc: 0.9570
#
# Epoch 138/199
# ----------
# Train Loss: 0.0454 Acc: 0.9825
# Val Loss: 0.1747 Acc: 0.9560
#
# Epoch 139/199
# ----------
# Train Loss: 0.0438 Acc: 0.9833
# Val Loss: 0.2830 Acc: 0.9200
#
# Epoch 140/199
# ----------
# Train Loss: 0.0627 Acc: 0.9773
# Val Loss: 0.4453 Acc: 0.8790
#
# Epoch 141/199
# ----------
# Train Loss: 0.0621 Acc: 0.9783
# Val Loss: 0.1577 Acc: 0.9590
#
# Epoch 142/199
# ----------
# Train Loss: 0.0398 Acc: 0.9863
# Val Loss: 0.1961 Acc: 0.9450
#
# Epoch 143/199
# ----------
# Train Loss: 0.0501 Acc: 0.9808
# Val Loss: 0.1493 Acc: 0.9620
#
# Epoch 144/199
# ----------
# Train Loss: 0.0485 Acc: 0.9835
# Val Loss: 0.1321 Acc: 0.9610
#
# Epoch 145/199
# ----------
# Train Loss: 0.0533 Acc: 0.9838
# Val Loss: 0.1642 Acc: 0.9500
#
# Epoch 146/199
# ----------
# Train Loss: 0.0602 Acc: 0.9788
# Val Loss: 0.1555 Acc: 0.9470
#
# Epoch 147/199
# ----------
# Train Loss: 0.0497 Acc: 0.9843
# Val Loss: 0.1232 Acc: 0.9600
#
# Epoch 148/199
# ----------
# Train Loss: 0.0332 Acc: 0.9880
# Val Loss: 0.2019 Acc: 0.9450
#
# Epoch 149/199
# ----------
# Train Loss: 0.0588 Acc: 0.9785
# Val Loss: 0.1430 Acc: 0.9530
#
# Epoch 150/199
# ----------
# Train Loss: 0.0502 Acc: 0.9833
# Val Loss: 0.1571 Acc: 0.9480
#
# Epoch 151/199
# ----------
# Train Loss: 0.0522 Acc: 0.9833
# Val Loss: 0.1631 Acc: 0.9580
#
# Epoch 152/199
# ----------
# Train Loss: 0.0286 Acc: 0.9903
# Val Loss: 0.1860 Acc: 0.9490
#
# Epoch 153/199
# ----------
# Train Loss: 0.0383 Acc: 0.9853
# Val Loss: 0.2261 Acc: 0.9270
#
# Epoch 154/199
# ----------
# Train Loss: 0.0469 Acc: 0.9850
# Val Loss: 0.2535 Acc: 0.9310
#
# Epoch 155/199
# ----------
# Train Loss: 0.0532 Acc: 0.9795
# Val Loss: 0.1778 Acc: 0.9400
#
# Epoch 156/199
# ----------
# Train Loss: 0.0807 Acc: 0.9738
# Val Loss: 0.1550 Acc: 0.9440
#
# Epoch 157/199
# ----------
# Train Loss: 0.0291 Acc: 0.9895
# Val Loss: 0.1691 Acc: 0.9440
#
# Epoch 158/199
# ----------
# Train Loss: 0.0348 Acc: 0.9895
# Val Loss: 0.1842 Acc: 0.9480
#
# Epoch 159/199
# ----------
# Train Loss: 0.0394 Acc: 0.9843
# Val Loss: 0.1883 Acc: 0.9480
#
# Epoch 160/199
# ----------
# Train Loss: 0.0456 Acc: 0.9843
# Val Loss: 0.1574 Acc: 0.9520
#
# Epoch 161/199
# ----------
# Train Loss: 0.0321 Acc: 0.9878
# Val Loss: 0.1623 Acc: 0.9580
#
# Epoch 162/199
# ----------
# Train Loss: 0.0373 Acc: 0.9868
# Val Loss: 0.1487 Acc: 0.9570
#
# Epoch 163/199
# ----------
# Train Loss: 0.0390 Acc: 0.9890
# Val Loss: 0.1389 Acc: 0.9590
#
# Epoch 164/199
# ----------
# Train Loss: 0.0341 Acc: 0.9865
# Val Loss: 0.1749 Acc: 0.9540
#
# Epoch 165/199
# ----------
# Train Loss: 0.0549 Acc: 0.9788
# Val Loss: 0.2029 Acc: 0.9440
#
# Epoch 166/199
# ----------
# Train Loss: 0.0498 Acc: 0.9815
# Val Loss: 0.1751 Acc: 0.9450
#
# Epoch 167/199
# ----------
# Train Loss: 0.0314 Acc: 0.9888
# Val Loss: 0.1774 Acc: 0.9540
#
# Epoch 168/199
# ----------
# Train Loss: 0.0304 Acc: 0.9873
# Val Loss: 0.2057 Acc: 0.9460
#
# Epoch 169/199
# ----------
# Train Loss: 0.0474 Acc: 0.9850
# Val Loss: 0.4238 Acc: 0.9020
#
# Epoch 170/199
# ----------
# Train Loss: 0.0616 Acc: 0.9810
# Val Loss: 0.1790 Acc: 0.9500
#
# Epoch 171/199
# ----------
# Train Loss: 0.0293 Acc: 0.9900
# Val Loss: 0.1904 Acc: 0.9540
#
# Epoch 172/199
# ----------
# Train Loss: 0.0482 Acc: 0.9818
# Val Loss: 0.1414 Acc: 0.9580
#
# Epoch 173/199
# ----------
# Train Loss: 0.0414 Acc: 0.9858
# Val Loss: 0.1601 Acc: 0.9590
#
# Epoch 174/199
# ----------
# Train Loss: 0.0360 Acc: 0.9868
# Val Loss: 0.1732 Acc: 0.9570
#
# Epoch 175/199
# ----------
# Train Loss: 0.0256 Acc: 0.9910
# Val Loss: 0.1844 Acc: 0.9600
#
# Epoch 176/199
# ----------
# Train Loss: 0.0372 Acc: 0.9855
# Val Loss: 0.1459 Acc: 0.9630
#
# Epoch 177/199
# ----------
# Train Loss: 0.0346 Acc: 0.9888
# Val Loss: 0.1479 Acc: 0.9640
#
# Epoch 178/199
# ----------
# Train Loss: 0.0345 Acc: 0.9873
# Val Loss: 0.1852 Acc: 0.9480
#
# Epoch 179/199
# ----------
# Train Loss: 0.0337 Acc: 0.9893
# Val Loss: 0.1743 Acc: 0.9540
#
# Epoch 180/199
# ----------
# Train Loss: 0.0361 Acc: 0.9888
# Val Loss: 0.1700 Acc: 0.9470
#
# Epoch 181/199
# ----------
# Train Loss: 0.0353 Acc: 0.9890
# Val Loss: 0.1679 Acc: 0.9560
#
# Epoch 182/199
# ----------
# Train Loss: 0.0350 Acc: 0.9873
# Val Loss: 0.1943 Acc: 0.9560
#
# Epoch 183/199
# ----------
# Train Loss: 0.0240 Acc: 0.9913
# Val Loss: 0.1580 Acc: 0.9590
#
# Epoch 184/199
# ----------
# Train Loss: 0.0377 Acc: 0.9860
# Val Loss: 0.1669 Acc: 0.9570
#
# Epoch 185/199
# ----------
# Train Loss: 0.0286 Acc: 0.9898
# Val Loss: 0.1481 Acc: 0.9550
#
# Epoch 186/199
# ----------
# Train Loss: 0.0545 Acc: 0.9828
# Val Loss: 0.1749 Acc: 0.9570
#
# Epoch 187/199
# ----------
# Train Loss: 0.0258 Acc: 0.9913
# Val Loss: 0.1900 Acc: 0.9540
#
# Epoch 188/199
# ----------
# Train Loss: 0.0417 Acc: 0.9865
# Val Loss: 0.1670 Acc: 0.9520
#
# Epoch 189/199
# ----------
# Train Loss: 0.0311 Acc: 0.9878
# Val Loss: 0.2079 Acc: 0.9380
#
# Epoch 190/199
# ----------
# Train Loss: 0.0406 Acc: 0.9865
# Val Loss: 0.2400 Acc: 0.9330
#
# Epoch 191/199
# ----------
# Train Loss: 0.0305 Acc: 0.9880
# Val Loss: 0.1473 Acc: 0.9620
#
# Epoch 192/199
# ----------
# Train Loss: 0.0281 Acc: 0.9895
# Val Loss: 0.1533 Acc: 0.9600
#
# Epoch 193/199
# ----------
# Train Loss: 0.0193 Acc: 0.9930
# Val Loss: 0.1661 Acc: 0.9600
#
# Epoch 194/199
# ----------
# Train Loss: 0.0331 Acc: 0.9885
# Val Loss: 0.1498 Acc: 0.9580
#
# Epoch 195/199
# ----------
# Train Loss: 0.0460 Acc: 0.9855
# Val Loss: 0.1338 Acc: 0.9630
#
# Epoch 196/199
# ----------
# Train Loss: 0.0256 Acc: 0.9920
# Val Loss: 0.1465 Acc: 0.9620
#
# Epoch 197/199
# ----------
# Train Loss: 0.0221 Acc: 0.9928
# Val Loss: 0.1762 Acc: 0.9540
#
# Epoch 198/199
# ----------
# Train Loss: 0.0264 Acc: 0.9898
# Val Loss: 0.1958 Acc: 0.9550
#
# Epoch 199/199
# ----------
# Train Loss: 0.0349 Acc: 0.9880
# Val Loss: 0.1963 Acc: 0.9500
#
# Training complete in 208m 26s
# Best val Acc: 0.964000
# Epoch 0/199
# ----------
# Train Loss: 0.8043 Acc: 0.7105
# Val Loss: 0.5178 Acc: 0.8100
#
# Epoch 1/199
# ----------
# Train Loss: 0.5435 Acc: 0.8040
# Val Loss: 0.9197 Acc: 0.6310
#
# Epoch 2/199
# ----------
# Train Loss: 0.5132 Acc: 0.8200
# Val Loss: 0.4394 Acc: 0.8230
#
# Epoch 3/199
# ----------
# Train Loss: 0.4396 Acc: 0.8405
# Val Loss: 0.5414 Acc: 0.7960
#
# Epoch 4/199
# ----------
# Train Loss: 0.3691 Acc: 0.8635
# Val Loss: 0.9065 Acc: 0.7420
#
# Epoch 5/199
# ----------
# Train Loss: 0.3663 Acc: 0.8635
# Val Loss: 0.4262 Acc: 0.8470
#
# Epoch 6/199
# ----------
# Train Loss: 0.4042 Acc: 0.8543
# Val Loss: 0.3750 Acc: 0.8430
#
# Epoch 7/199
# ----------
# Train Loss: 0.3554 Acc: 0.8725
# Val Loss: 0.4805 Acc: 0.7910
#
# Epoch 8/199
# ----------
# Train Loss: 0.3196 Acc: 0.8845
# Val Loss: 0.3129 Acc: 0.8850
#
# Epoch 9/199
# ----------
# Train Loss: 0.3145 Acc: 0.8900
# Val Loss: 0.4142 Acc: 0.8430
#
# Epoch 10/199
# ----------
# Train Loss: 0.2911 Acc: 0.8960
# Val Loss: 0.3947 Acc: 0.8420
#
# Epoch 11/199
# ----------
# Train Loss: 0.3071 Acc: 0.8938
# Val Loss: 0.3128 Acc: 0.8680
#
# Epoch 12/199
# ----------
# Train Loss: 0.2657 Acc: 0.9028
# Val Loss: 0.3047 Acc: 0.8830
#
# Epoch 13/199
# ----------
# Train Loss: 0.2540 Acc: 0.9143
# Val Loss: 0.3285 Acc: 0.8560
#
# Epoch 14/199
# ----------
# Train Loss: 0.2505 Acc: 0.9113
# Val Loss: 0.2162 Acc: 0.9120
#
# Epoch 15/199
# ----------
# Train Loss: 0.2391 Acc: 0.9123
# Val Loss: 0.3602 Acc: 0.8790
#
# Epoch 16/199
# ----------
# Train Loss: 0.2648 Acc: 0.9083
# Val Loss: 0.2129 Acc: 0.9130
#
# Epoch 17/199
# ----------
# Train Loss: 0.2278 Acc: 0.9168
# Val Loss: 0.2462 Acc: 0.9050
#
# Epoch 18/199
# ----------
# Train Loss: 0.2148 Acc: 0.9220
# Val Loss: 0.2359 Acc: 0.9090
#
# Epoch 19/199
# ----------
# Train Loss: 0.2167 Acc: 0.9178
# Val Loss: 0.1986 Acc: 0.9190
#
# Epoch 20/199
# ----------
# Train Loss: 0.2091 Acc: 0.9218
# Val Loss: 0.3363 Acc: 0.8930
#
# Epoch 21/199
# ----------
# Train Loss: 0.2416 Acc: 0.9148
# Val Loss: 0.2180 Acc: 0.9230
#
# Epoch 22/199
# ----------
# Train Loss: 0.1767 Acc: 0.9377
# Val Loss: 0.3915 Acc: 0.8750
#
# Epoch 23/199
# ----------
# Train Loss: 0.2029 Acc: 0.9240
# Val Loss: 0.2186 Acc: 0.9140
#
# Epoch 24/199
# ----------
# Train Loss: 0.1795 Acc: 0.9307
# Val Loss: 0.2104 Acc: 0.9120
#
# Epoch 25/199
# ----------
# Train Loss: 0.1892 Acc: 0.9297
# Val Loss: 0.1806 Acc: 0.9310
#
# Epoch 26/199
# ----------
# Train Loss: 0.1853 Acc: 0.9293
# Val Loss: 0.1944 Acc: 0.9160
#
# Epoch 27/199
# ----------
# Train Loss: 0.1833 Acc: 0.9345
# Val Loss: 0.3599 Acc: 0.8710
#
# Epoch 28/199
# ----------
# Train Loss: 0.1991 Acc: 0.9280
# Val Loss: 0.1866 Acc: 0.9260
#
# Epoch 29/199
# ----------
# Train Loss: 0.2084 Acc: 0.9265
# Val Loss: 0.2541 Acc: 0.8950
#
# Epoch 30/199
# ----------
# Train Loss: 0.1729 Acc: 0.9385
# Val Loss: 0.1867 Acc: 0.9260
#
# Epoch 31/199
# ----------
# Train Loss: 0.1643 Acc: 0.9410
# Val Loss: 0.3079 Acc: 0.8890
#
# Epoch 32/199
# ----------
# Train Loss: 0.1735 Acc: 0.9343
# Val Loss: 0.1834 Acc: 0.9300
#
# Epoch 33/199
# ----------
# Train Loss: 0.1607 Acc: 0.9395
# Val Loss: 0.1863 Acc: 0.9230
#
# Epoch 34/199
# ----------
# Train Loss: 0.1790 Acc: 0.9373
# Val Loss: 0.1770 Acc: 0.9280
#
# Epoch 35/199
# ----------
# Train Loss: 0.1580 Acc: 0.9395
# Val Loss: 0.3007 Acc: 0.9010
#
# Epoch 36/199
# ----------
# Train Loss: 0.1573 Acc: 0.9425
# Val Loss: 0.2575 Acc: 0.9010
#
# Epoch 37/199
# ----------
# Train Loss: 0.1554 Acc: 0.9397
# Val Loss: 0.2093 Acc: 0.9150
#
# Epoch 38/199
# ----------
# Train Loss: 0.1319 Acc: 0.9530
# Val Loss: 0.1750 Acc: 0.9360
#
# Epoch 39/199
# ----------
# Train Loss: 0.1279 Acc: 0.9530
# Val Loss: 0.1673 Acc: 0.9330
#
# Epoch 40/199
# ----------
# Train Loss: 0.1656 Acc: 0.9415
# Val Loss: 0.1891 Acc: 0.9220
#
# Epoch 41/199
# ----------
# Train Loss: 0.1416 Acc: 0.9447
# Val Loss: 0.2036 Acc: 0.9290
#
# Epoch 42/199
# ----------
# Train Loss: 0.1477 Acc: 0.9457
# Val Loss: 0.1911 Acc: 0.9270
#
# Epoch 43/199
# ----------
# Train Loss: 0.1434 Acc: 0.9475
# Val Loss: 0.3412 Acc: 0.8860
#
# Epoch 44/199
# ----------
# Train Loss: 0.1321 Acc: 0.9495
# Val Loss: 0.2175 Acc: 0.9200
#
# Epoch 45/199
# ----------
# Train Loss: 0.1332 Acc: 0.9505
# Val Loss: 0.2194 Acc: 0.9210
#
# Epoch 46/199
# ----------
# Train Loss: 0.1579 Acc: 0.9440
# Val Loss: 0.2022 Acc: 0.9300
#
# Epoch 47/199
# ----------
# Train Loss: 0.1336 Acc: 0.9505
# Val Loss: 0.2131 Acc: 0.9260
#
# Epoch 48/199
# ----------
# Train Loss: 0.1366 Acc: 0.9507
# Val Loss: 0.1629 Acc: 0.9490
#
# Epoch 49/199
# ----------
# Train Loss: 0.1239 Acc: 0.9517
# Val Loss: 0.1735 Acc: 0.9390
#
# Epoch 50/199
# ----------
# Train Loss: 0.1173 Acc: 0.9557
# Val Loss: 0.1677 Acc: 0.9330
#
# Epoch 51/199
# ----------
# Train Loss: 0.1245 Acc: 0.9553
# Val Loss: 0.7830 Acc: 0.7950
#
# Epoch 52/199
# ----------
# Train Loss: 0.1389 Acc: 0.9523
# Val Loss: 0.2462 Acc: 0.9110
#
# Epoch 53/199
# ----------
# Train Loss: 0.1173 Acc: 0.9590
# Val Loss: 0.1275 Acc: 0.9540
#
# Epoch 54/199
# ----------
# Train Loss: 0.1146 Acc: 0.9555
# Val Loss: 0.2653 Acc: 0.9010
#
# Epoch 55/199
# ----------
# Train Loss: 0.1227 Acc: 0.9533
# Val Loss: 0.3391 Acc: 0.8800
#
# Epoch 56/199
# ----------
# Train Loss: 0.1342 Acc: 0.9505
# Val Loss: 0.1872 Acc: 0.9280
#
# Epoch 57/199
# ----------
# Train Loss: 0.1238 Acc: 0.9555
# Val Loss: 0.1303 Acc: 0.9460
#
# Epoch 58/199
# ----------
# Train Loss: 0.1214 Acc: 0.9550
# Val Loss: 0.1669 Acc: 0.9340
#
# Epoch 59/199
# ----------
# Train Loss: 0.1054 Acc: 0.9603
# Val Loss: 0.1997 Acc: 0.9280
#
# Epoch 60/199
# ----------
# Train Loss: 0.1321 Acc: 0.9523
# Val Loss: 0.1667 Acc: 0.9410
#
# Epoch 61/199
# ----------
# Train Loss: 0.0985 Acc: 0.9630
# Val Loss: 0.1721 Acc: 0.9420
#
# Epoch 62/199
# ----------
# Train Loss: 0.1549 Acc: 0.9487
# Val Loss: 0.1720 Acc: 0.9300
#
# Epoch 63/199
# ----------
# Train Loss: 0.1077 Acc: 0.9587
# Val Loss: 0.1624 Acc: 0.9430
#
# Epoch 64/199
# ----------
# Train Loss: 0.1068 Acc: 0.9597
# Val Loss: 0.1632 Acc: 0.9330
#
# Epoch 65/199
# ----------
# Train Loss: 0.1050 Acc: 0.9610
# Val Loss: 0.1758 Acc: 0.9270
#
# Epoch 66/199
# ----------
# Train Loss: 0.0959 Acc: 0.9630
# Val Loss: 0.1496 Acc: 0.9430
#
# Epoch 67/199
# ----------
# Train Loss: 0.0923 Acc: 0.9640
# Val Loss: 0.2277 Acc: 0.9410
#
# Epoch 68/199
# ----------
# Train Loss: 0.1114 Acc: 0.9573
# Val Loss: 0.1572 Acc: 0.9330
#
# Epoch 69/199
# ----------
# Train Loss: 0.1085 Acc: 0.9620
# Val Loss: 0.2175 Acc: 0.9200
#
# Epoch 70/199
# ----------
# Train Loss: 0.1211 Acc: 0.9600
# Val Loss: 0.1377 Acc: 0.9500
#
# Epoch 71/199
# ----------
# Train Loss: 0.0885 Acc: 0.9635
# Val Loss: 0.1352 Acc: 0.9470
#
# Epoch 72/199
# ----------
# Train Loss: 0.0965 Acc: 0.9623
# Val Loss: 0.1428 Acc: 0.9450
#
# Epoch 73/199
# ----------
# Train Loss: 0.1080 Acc: 0.9580
# Val Loss: 0.1763 Acc: 0.9360
#
# Epoch 74/199
# ----------
# Train Loss: 0.1049 Acc: 0.9650
# Val Loss: 0.1738 Acc: 0.9430
#
# Epoch 75/199
# ----------
# Train Loss: 0.0983 Acc: 0.9635
# Val Loss: 0.1284 Acc: 0.9580
#
# Epoch 76/199
# ----------
# Train Loss: 0.0861 Acc: 0.9695
# Val Loss: 0.1420 Acc: 0.9390
#
# Epoch 77/199
# ----------
# Train Loss: 0.1251 Acc: 0.9573
# Val Loss: 0.2358 Acc: 0.9210
#
# Epoch 78/199
# ----------
# Train Loss: 0.0934 Acc: 0.9645
# Val Loss: 0.1269 Acc: 0.9560
#
# Epoch 79/199
# ----------
# Train Loss: 0.0830 Acc: 0.9708
# Val Loss: 0.1907 Acc: 0.9400
#
# Epoch 80/199
# ----------
# Train Loss: 0.0874 Acc: 0.9653
# Val Loss: 0.1301 Acc: 0.9520
#
# Epoch 81/199
# ----------
# Train Loss: 0.0839 Acc: 0.9710
# Val Loss: 0.1486 Acc: 0.9550
#
# Epoch 82/199
# ----------
# Train Loss: 0.0682 Acc: 0.9738
# Val Loss: 0.1831 Acc: 0.9470
#
# Epoch 83/199
# ----------
# Train Loss: 0.0882 Acc: 0.9670
# Val Loss: 0.2432 Acc: 0.9370
#
# Epoch 84/199
# ----------
# Train Loss: 0.1183 Acc: 0.9607
# Val Loss: 0.6293 Acc: 0.8470
#
# Epoch 85/199
# ----------
# Train Loss: 0.1064 Acc: 0.9627
# Val Loss: 0.1431 Acc: 0.9450
#
# Epoch 86/199
# ----------
# Train Loss: 0.0918 Acc: 0.9683
# Val Loss: 0.1605 Acc: 0.9470
#
# Epoch 87/199
# ----------
# Train Loss: 0.0731 Acc: 0.9728
# Val Loss: 0.1734 Acc: 0.9440
#
# Epoch 88/199
# ----------
# Train Loss: 0.0759 Acc: 0.9720
# Val Loss: 0.1504 Acc: 0.9540
#
# Epoch 89/199
# ----------
# Train Loss: 0.0906 Acc: 0.9667
# Val Loss: 0.1492 Acc: 0.9540
#
# Epoch 90/199
# ----------
# Train Loss: 0.0849 Acc: 0.9673
# Val Loss: 0.2002 Acc: 0.9370
#
# Epoch 91/199
# ----------
# Train Loss: 0.0995 Acc: 0.9640
# Val Loss: 0.1494 Acc: 0.9510
#
# Epoch 92/199
# ----------
# Train Loss: 0.0743 Acc: 0.9733
# Val Loss: 0.3126 Acc: 0.8940
#
# Epoch 93/199
# ----------
# Train Loss: 0.0789 Acc: 0.9723
# Val Loss: 0.1902 Acc: 0.9430
#
# Epoch 94/199
# ----------
# Train Loss: 0.0710 Acc: 0.9740
# Val Loss: 0.1497 Acc: 0.9440
#
# Epoch 95/199
# ----------
# Train Loss: 0.0684 Acc: 0.9755
# Val Loss: 0.1714 Acc: 0.9420
#
# Epoch 96/199
# ----------
# Train Loss: 0.0779 Acc: 0.9738
# Val Loss: 0.1275 Acc: 0.9530
#
# Epoch 97/199
# ----------
# Train Loss: 0.0730 Acc: 0.9745
# Val Loss: 0.1944 Acc: 0.9440
#
# Epoch 98/199
# ----------
# Train Loss: 0.0704 Acc: 0.9758
# Val Loss: 0.1398 Acc: 0.9560
#
# Epoch 99/199
# ----------
# Train Loss: 0.0705 Acc: 0.9725
# Val Loss: 0.1608 Acc: 0.9540
#
# Epoch 100/199
# ----------
# Train Loss: 0.0818 Acc: 0.9710
# Val Loss: 0.1339 Acc: 0.9490
#
# Epoch 101/199
# ----------
# Train Loss: 0.0751 Acc: 0.9713
# Val Loss: 0.2098 Acc: 0.9360
#
# Epoch 102/199
# ----------
# Train Loss: 0.0680 Acc: 0.9740
# Val Loss: 0.1484 Acc: 0.9460
#
# Epoch 103/199
# ----------
# Train Loss: 0.0644 Acc: 0.9763
# Val Loss: 0.1327 Acc: 0.9500
#
# Epoch 104/199
# ----------
# Train Loss: 0.0909 Acc: 0.9690
# Val Loss: 0.1214 Acc: 0.9560
#
# Epoch 105/199
# ----------
# Train Loss: 0.0743 Acc: 0.9728
# Val Loss: 0.1561 Acc: 0.9480
#
# Epoch 106/199
# ----------
# Train Loss: 0.0753 Acc: 0.9743
# Val Loss: 0.1489 Acc: 0.9470
#
# Epoch 107/199
# ----------
# Train Loss: 0.0688 Acc: 0.9758
# Val Loss: 0.1797 Acc: 0.9450
#
# Epoch 108/199
# ----------
# Train Loss: 0.0610 Acc: 0.9728
# Val Loss: 0.1360 Acc: 0.9510
#
# Epoch 109/199
# ----------
# Train Loss: 0.0685 Acc: 0.9753
# Val Loss: 0.1951 Acc: 0.9360
#
# Epoch 110/199
# ----------
# Train Loss: 0.0798 Acc: 0.9743
# Val Loss: 0.1876 Acc: 0.9380
#
# Epoch 111/199
# ----------
# Train Loss: 0.0526 Acc: 0.9798
# Val Loss: 0.1533 Acc: 0.9550
#
# Epoch 112/199
# ----------
# Train Loss: 0.0697 Acc: 0.9740
# Val Loss: 0.1293 Acc: 0.9570
#
# Epoch 113/199
# ----------
# Train Loss: 0.0825 Acc: 0.9705
# Val Loss: 0.1567 Acc: 0.9460
#
# Epoch 114/199
# ----------
# Train Loss: 0.0778 Acc: 0.9705
# Val Loss: 0.1226 Acc: 0.9520
#
# Epoch 115/199
# ----------
# Train Loss: 0.0591 Acc: 0.9788
# Val Loss: 0.1419 Acc: 0.9550
#
# Epoch 116/199
# ----------
# Train Loss: 0.0520 Acc: 0.9810
# Val Loss: 0.1991 Acc: 0.9370
#
# Epoch 117/199
# ----------
# Train Loss: 0.0599 Acc: 0.9783
# Val Loss: 0.1648 Acc: 0.9550
#
# Epoch 118/199
# ----------
# Train Loss: 0.0669 Acc: 0.9778
# Val Loss: 0.2100 Acc: 0.9290
#
# Epoch 119/199
# ----------
# Train Loss: 0.0592 Acc: 0.9768
# Val Loss: 0.1403 Acc: 0.9600
#
# Epoch 120/199
# ----------
# Train Loss: 0.0547 Acc: 0.9778
# Val Loss: 0.1461 Acc: 0.9560
#
# Epoch 121/199
# ----------
# Train Loss: 0.0698 Acc: 0.9775
# Val Loss: 0.1692 Acc: 0.9420
#
# Epoch 122/199
# ----------
# Train Loss: 0.0684 Acc: 0.9738
# Val Loss: 0.1504 Acc: 0.9540
#
# Epoch 123/199
# ----------
# Train Loss: 0.0473 Acc: 0.9828
# Val Loss: 0.1849 Acc: 0.9410
#
# Epoch 124/199
# ----------
# Train Loss: 0.0464 Acc: 0.9838
# Val Loss: 0.1731 Acc: 0.9440
#
# Epoch 125/199
# ----------
# Train Loss: 0.0631 Acc: 0.9763
# Val Loss: 0.2434 Acc: 0.9240
#
# Epoch 126/199
# ----------
# Train Loss: 0.0561 Acc: 0.9795
# Val Loss: 0.1531 Acc: 0.9550
#
# Epoch 127/199
# ----------
# Train Loss: 0.0746 Acc: 0.9725
# Val Loss: 0.1957 Acc: 0.9330
#
# Epoch 128/199
# ----------
# Train Loss: 0.0522 Acc: 0.9805
# Val Loss: 0.1681 Acc: 0.9420
#
# Epoch 129/199
# ----------
# Train Loss: 0.0502 Acc: 0.9805
# Val Loss: 0.1488 Acc: 0.9510
#
# Epoch 130/199
# ----------
# Train Loss: 0.0428 Acc: 0.9828
# Val Loss: 0.2192 Acc: 0.9350
#
# Epoch 131/199
# ----------
# Train Loss: 0.0496 Acc: 0.9790
# Val Loss: 0.1519 Acc: 0.9530
#
# Epoch 132/199
# ----------
# Train Loss: 0.0539 Acc: 0.9803
# Val Loss: 0.3196 Acc: 0.9160
#
# Epoch 133/199
# ----------
# Train Loss: 0.0504 Acc: 0.9820
# Val Loss: 0.2047 Acc: 0.9550
#
# Epoch 134/199
# ----------
# Train Loss: 0.0480 Acc: 0.9825
# Val Loss: 0.1516 Acc: 0.9560
#
# Epoch 135/199
# ----------
# Train Loss: 0.0520 Acc: 0.9793
# Val Loss: 0.2385 Acc: 0.9340
#
# Epoch 136/199
# ----------
# Train Loss: 0.0658 Acc: 0.9783
# Val Loss: 0.1488 Acc: 0.9490
#
# Epoch 137/199
# ----------
# Train Loss: 0.0366 Acc: 0.9853
# Val Loss: 0.1577 Acc: 0.9620
#
# Epoch 138/199
# ----------
# Train Loss: 0.0457 Acc: 0.9848
# Val Loss: 0.1562 Acc: 0.9520
#
# Epoch 139/199
# ----------
# Train Loss: 0.0562 Acc: 0.9805
# Val Loss: 0.1289 Acc: 0.9540
#
# Epoch 140/199
# ----------
# Train Loss: 0.0534 Acc: 0.9803
# Val Loss: 0.1466 Acc: 0.9570
#
# Epoch 141/199
# ----------
# Train Loss: 0.0384 Acc: 0.9878
# Val Loss: 0.1431 Acc: 0.9560
#
# Epoch 142/199
# ----------
# Train Loss: 0.0457 Acc: 0.9835
# Val Loss: 0.2158 Acc: 0.9350
#
# Epoch 143/199
# ----------
# Train Loss: 0.0406 Acc: 0.9855
# Val Loss: 0.1620 Acc: 0.9540
#
# Epoch 144/199
# ----------
# Train Loss: 0.0474 Acc: 0.9815
# Val Loss: 0.1572 Acc: 0.9530
#
# Epoch 145/199
# ----------
# Train Loss: 0.0582 Acc: 0.9788
# Val Loss: 0.2179 Acc: 0.9470
#
# Epoch 146/199
# ----------
# Train Loss: 0.0414 Acc: 0.9843
# Val Loss: 0.1887 Acc: 0.9510
#
# Epoch 147/199
# ----------
# Train Loss: 0.0460 Acc: 0.9828
# Val Loss: 0.2289 Acc: 0.9520
#
# Epoch 148/199
# ----------
# Train Loss: 0.0574 Acc: 0.9808
# Val Loss: 0.1725 Acc: 0.9540
#
# Epoch 149/199
# ----------
# Train Loss: 0.0459 Acc: 0.9840
# Val Loss: 0.1901 Acc: 0.9470
#
# Epoch 150/199
# ----------
# Train Loss: 0.0390 Acc: 0.9848
# Val Loss: 0.1565 Acc: 0.9620
#
# Epoch 151/199
# ----------
# Train Loss: 0.0381 Acc: 0.9848
# Val Loss: 0.1952 Acc: 0.9450
#
# Epoch 152/199
# ----------
# Train Loss: 0.0447 Acc: 0.9843
# Val Loss: 0.1761 Acc: 0.9560
#
# Epoch 153/199
# ----------
# Train Loss: 0.0393 Acc: 0.9843
# Val Loss: 0.2680 Acc: 0.9310
#
# Epoch 154/199
# ----------
# Train Loss: 0.0414 Acc: 0.9863
# Val Loss: 0.1606 Acc: 0.9520
#
# Epoch 155/199
# ----------
# Train Loss: 0.0398 Acc: 0.9843
# Val Loss: 0.1810 Acc: 0.9490
#
# Epoch 156/199
# ----------
# Train Loss: 0.0823 Acc: 0.9745
# Val Loss: 0.1402 Acc: 0.9660
#
# Epoch 157/199
# ----------
# Train Loss: 0.0262 Acc: 0.9903
# Val Loss: 0.1888 Acc: 0.9500
#
# Epoch 158/199
# ----------
# Train Loss: 0.0395 Acc: 0.9863
# Val Loss: 0.1530 Acc: 0.9550
#
# Epoch 159/199
# ----------
# Train Loss: 0.0709 Acc: 0.9750
# Val Loss: 0.1253 Acc: 0.9580
#
# Epoch 160/199
# ----------
# Train Loss: 0.0611 Acc: 0.9805
# Val Loss: 0.1359 Acc: 0.9520
#
# Epoch 161/199
# ----------
# Train Loss: 0.0327 Acc: 0.9895
# Val Loss: 0.1386 Acc: 0.9550
#
# Epoch 162/199
# ----------
# Train Loss: 0.0288 Acc: 0.9900
# Val Loss: 0.1825 Acc: 0.9530
#
# Epoch 163/199
# ----------
# Train Loss: 0.0368 Acc: 0.9853
# Val Loss: 0.1231 Acc: 0.9660
#
# Epoch 164/199
# ----------
# Train Loss: 0.0327 Acc: 0.9885
# Val Loss: 0.1810 Acc: 0.9530
#
# Epoch 165/199
# ----------
# Train Loss: 0.0329 Acc: 0.9883
# Val Loss: 0.1817 Acc: 0.9430
#
# Epoch 166/199
# ----------
# Train Loss: 0.0443 Acc: 0.9835
# Val Loss: 0.1976 Acc: 0.9450
#
# Epoch 167/199
# ----------
# Train Loss: 0.0373 Acc: 0.9878
# Val Loss: 0.1805 Acc: 0.9460
#
# Epoch 168/199
# ----------
# Train Loss: 0.0259 Acc: 0.9893
# Val Loss: 0.1681 Acc: 0.9510
#
# Epoch 169/199
# ----------
# Train Loss: 0.0370 Acc: 0.9858
# Val Loss: 0.1602 Acc: 0.9520
#
# Epoch 170/199
# ----------
# Train Loss: 0.0393 Acc: 0.9865
# Val Loss: 0.1698 Acc: 0.9470
#
# Epoch 171/199
# ----------
# Train Loss: 0.0386 Acc: 0.9883
# Val Loss: 0.1769 Acc: 0.9540
#
# Epoch 172/199
# ----------
# Train Loss: 0.0261 Acc: 0.9910
# Val Loss: 0.1810 Acc: 0.9530
#
# Epoch 173/199
# ----------
# Train Loss: 0.0738 Acc: 0.9785
# Val Loss: 0.2128 Acc: 0.9410
#
# Epoch 174/199
# ----------
# Train Loss: 0.0291 Acc: 0.9898
# Val Loss: 0.2238 Acc: 0.9470
#
# Epoch 175/199
# ----------
# Train Loss: 0.0389 Acc: 0.9875
# Val Loss: 0.1848 Acc: 0.9500
#
# Epoch 176/199
# ----------
# Train Loss: 0.0303 Acc: 0.9878
# Val Loss: 0.1616 Acc: 0.9480
#
# Epoch 177/199
# ----------
# Train Loss: 0.0457 Acc: 0.9838
# Val Loss: 0.1745 Acc: 0.9460
#
# Epoch 178/199
# ----------
# Train Loss: 0.0251 Acc: 0.9900
# Val Loss: 0.2053 Acc: 0.9560
#
# Epoch 179/199
# ----------
# Train Loss: 0.0196 Acc: 0.9918
# Val Loss: 0.1915 Acc: 0.9570
#
# Epoch 180/199
# ----------
# Train Loss: 0.0454 Acc: 0.9885
# Val Loss: 0.1796 Acc: 0.9510
#
# Epoch 181/199
# ----------
# Train Loss: 0.0295 Acc: 0.9895
# Val Loss: 0.1698 Acc: 0.9540
#
# Epoch 182/199
# ----------
# Train Loss: 0.0363 Acc: 0.9873
# Val Loss: 0.2104 Acc: 0.9470
#
# Epoch 183/199
# ----------
# Train Loss: 0.0331 Acc: 0.9888
# Val Loss: 0.1566 Acc: 0.9610
#
# Epoch 184/199
# ----------
# Train Loss: 0.0283 Acc: 0.9913
# Val Loss: 0.1860 Acc: 0.9470
#
# Epoch 185/199
# ----------
# Train Loss: 0.0292 Acc: 0.9908
# Val Loss: 0.1806 Acc: 0.9560
#
# Epoch 186/199
# ----------
# Train Loss: 0.0324 Acc: 0.9893
# Val Loss: 0.1632 Acc: 0.9550
#
# Epoch 187/199
# ----------
# Train Loss: 0.0319 Acc: 0.9880
# Val Loss: 0.2361 Acc: 0.9440
#
# Epoch 188/199
# ----------
# Train Loss: 0.0349 Acc: 0.9873
# Val Loss: 0.1909 Acc: 0.9520
#
# Epoch 189/199
# ----------
# Train Loss: 0.0262 Acc: 0.9913
# Val Loss: 0.1908 Acc: 0.9480
#
# Epoch 190/199
# ----------
# Train Loss: 0.0240 Acc: 0.9908
# Val Loss: 0.1595 Acc: 0.9620
#
# Epoch 191/199
# ----------
# Train Loss: 0.0300 Acc: 0.9875
# Val Loss: 0.3150 Acc: 0.9450
#
# Epoch 192/199
# ----------
# Train Loss: 0.0342 Acc: 0.9883
# Val Loss: 0.3653 Acc: 0.9350
#
# Epoch 193/199
# ----------
# Train Loss: 0.0468 Acc: 0.9873
# Val Loss: 0.2515 Acc: 0.9310
#
# Epoch 194/199
# ----------
# Train Loss: 0.0873 Acc: 0.9765
# Val Loss: 0.1623 Acc: 0.9500
#
# Epoch 195/199
# ----------
# Train Loss: 0.0390 Acc: 0.9880
# Val Loss: 0.1422 Acc: 0.9560
#
# Epoch 196/199
# ----------
# Train Loss: 0.0304 Acc: 0.9895
# Val Loss: 0.1486 Acc: 0.9620
#
# Epoch 197/199
# ----------
# Train Loss: 0.0216 Acc: 0.9915
# Val Loss: 0.1923 Acc: 0.9550
#
# Epoch 198/199
# ----------
# Train Loss: 0.0346 Acc: 0.9878
# Val Loss: 0.1962 Acc: 0.9470
#
# Epoch 199/199
# ----------
# Train Loss: 0.0245 Acc: 0.9920
# Val Loss: 0.2119 Acc: 0.9530
#
# Training complete in 207m 39s
# Best val Acc: 0.966000
# Epoch 0/199
# ----------
# Train Loss: 0.8562 Acc: 0.6993
# Val Loss: 0.7117 Acc: 0.7450
#
# Epoch 1/199
# ----------
# Train Loss: 0.5731 Acc: 0.7983
# Val Loss: 0.5436 Acc: 0.8050
#
# Epoch 2/199
# ----------
# Train Loss: 0.4683 Acc: 0.8295
# Val Loss: 0.5359 Acc: 0.7990
#
# Epoch 3/199
# ----------
# Train Loss: 0.4338 Acc: 0.8317
# Val Loss: 0.3549 Acc: 0.8630
#
# Epoch 4/199
# ----------
# Train Loss: 0.4183 Acc: 0.8490
# Val Loss: 0.5654 Acc: 0.8250
#
# Epoch 5/199
# ----------
# Train Loss: 0.3834 Acc: 0.8613
# Val Loss: 0.4114 Acc: 0.8590
#
# Epoch 6/199
# ----------
# Train Loss: 0.3653 Acc: 0.8678
# Val Loss: 0.4939 Acc: 0.8100
#
# Epoch 7/199
# ----------
# Train Loss: 0.3678 Acc: 0.8678
# Val Loss: 0.3328 Acc: 0.8730
#
# Epoch 8/199
# ----------
# Train Loss: 0.3146 Acc: 0.8878
# Val Loss: 0.2496 Acc: 0.9000
#
# Epoch 9/199
# ----------
# Train Loss: 0.2866 Acc: 0.8950
# Val Loss: 0.3956 Acc: 0.8620
#
# Epoch 10/199
# ----------
# Train Loss: 0.3032 Acc: 0.8938
# Val Loss: 0.2267 Acc: 0.9030
#
# Epoch 11/199
# ----------
# Train Loss: 0.2629 Acc: 0.8995
# Val Loss: 0.3741 Acc: 0.8680
#
# Epoch 12/199
# ----------
# Train Loss: 0.2917 Acc: 0.8945
# Val Loss: 0.4089 Acc: 0.8410
#
# Epoch 13/199
# ----------
# Train Loss: 0.2758 Acc: 0.8990
# Val Loss: 0.2806 Acc: 0.8770
#
# Epoch 14/199
# ----------
# Train Loss: 0.2618 Acc: 0.9010
# Val Loss: 1.0327 Acc: 0.7390
#
# Epoch 15/199
# ----------
# Train Loss: 0.2422 Acc: 0.9075
# Val Loss: 0.2235 Acc: 0.9160
#
# Epoch 16/199
# ----------
# Train Loss: 0.3095 Acc: 0.8908
# Val Loss: 0.2784 Acc: 0.8870
#
# Epoch 17/199
# ----------
# Train Loss: 0.2453 Acc: 0.9085
# Val Loss: 0.4111 Acc: 0.8480
#
# Epoch 18/199
# ----------
# Train Loss: 0.2182 Acc: 0.9185
# Val Loss: 0.2607 Acc: 0.9040
#
# Epoch 19/199
# ----------
# Train Loss: 0.2230 Acc: 0.9225
# Val Loss: 0.4264 Acc: 0.8360
#
# Epoch 20/199
# ----------
# Train Loss: 0.2176 Acc: 0.9193
# Val Loss: 0.3014 Acc: 0.8960
#
# Epoch 21/199
# ----------
# Train Loss: 0.2228 Acc: 0.9153
# Val Loss: 0.2494 Acc: 0.9050
#
# Epoch 22/199
# ----------
# Train Loss: 0.2271 Acc: 0.9168
# Val Loss: 0.2346 Acc: 0.9130
#
# Epoch 23/199
# ----------
# Train Loss: 0.1987 Acc: 0.9228
# Val Loss: 0.1716 Acc: 0.9270
#
# Epoch 24/199
# ----------
# Train Loss: 0.1854 Acc: 0.9313
# Val Loss: 0.2731 Acc: 0.8890
#
# Epoch 25/199
# ----------
# Train Loss: 0.1694 Acc: 0.9360
# Val Loss: 0.2139 Acc: 0.9190
#
# Epoch 26/199
# ----------
# Train Loss: 0.2048 Acc: 0.9260
# Val Loss: 0.2763 Acc: 0.8990
#
# Epoch 27/199
# ----------
# Train Loss: 0.1937 Acc: 0.9273
# Val Loss: 0.2190 Acc: 0.9160
#
# Epoch 28/199
# ----------
# Train Loss: 0.1872 Acc: 0.9335
# Val Loss: 0.5682 Acc: 0.8400
#
# Epoch 29/199
# ----------
# Train Loss: 0.2367 Acc: 0.9178
# Val Loss: 0.2912 Acc: 0.8950
#
# Epoch 30/199
# ----------
# Train Loss: 0.1874 Acc: 0.9323
# Val Loss: 0.2339 Acc: 0.9060
#
# Epoch 31/199
# ----------
# Train Loss: 0.1591 Acc: 0.9403
# Val Loss: 0.2308 Acc: 0.9130
#
# Epoch 32/199
# ----------
# Train Loss: 0.1764 Acc: 0.9347
# Val Loss: 0.2031 Acc: 0.9260
#
# Epoch 33/199
# ----------
# Train Loss: 0.1681 Acc: 0.9340
# Val Loss: 0.2191 Acc: 0.9260
#
# Epoch 34/199
# ----------
# Train Loss: 0.1595 Acc: 0.9395
# Val Loss: 0.1954 Acc: 0.9320
#
# Epoch 35/199
# ----------
# Train Loss: 0.1561 Acc: 0.9430
# Val Loss: 0.1667 Acc: 0.9350
#
# Epoch 36/199
# ----------
# Train Loss: 0.1459 Acc: 0.9443
# Val Loss: 0.1641 Acc: 0.9360
#
# Epoch 37/199
# ----------
# Train Loss: 0.1434 Acc: 0.9433
# Val Loss: 0.1698 Acc: 0.9310
#
# Epoch 38/199
# ----------
# Train Loss: 0.1385 Acc: 0.9487
# Val Loss: 0.2133 Acc: 0.9100
#
# Epoch 39/199
# ----------
# Train Loss: 0.1533 Acc: 0.9460
# Val Loss: 0.1744 Acc: 0.9350
#
# Epoch 40/199
# ----------
# Train Loss: 0.1487 Acc: 0.9490
# Val Loss: 0.1676 Acc: 0.9390
#
# Epoch 41/199
# ----------
# Train Loss: 0.1340 Acc: 0.9520
# Val Loss: 0.1538 Acc: 0.9400
#
# Epoch 42/199
# ----------
# Train Loss: 0.2149 Acc: 0.9263
# Val Loss: 0.1930 Acc: 0.9200
#
# Epoch 43/199
# ----------
# Train Loss: 0.1453 Acc: 0.9457
# Val Loss: 0.2035 Acc: 0.9250
#
# Epoch 44/199
# ----------
# Train Loss: 0.1664 Acc: 0.9397
# Val Loss: 0.2191 Acc: 0.9130
#
# Epoch 45/199
# ----------
# Train Loss: 0.1532 Acc: 0.9480
# Val Loss: 0.2307 Acc: 0.9110
#
# Epoch 46/199
# ----------
# Train Loss: 0.1215 Acc: 0.9535
# Val Loss: 0.1718 Acc: 0.9360
#
# Epoch 47/199
# ----------
# Train Loss: 0.1251 Acc: 0.9485
# Val Loss: 0.1677 Acc: 0.9380
#
# Epoch 48/199
# ----------
# Train Loss: 0.1330 Acc: 0.9465
# Val Loss: 0.1768 Acc: 0.9320
#
# Epoch 49/199
# ----------
# Train Loss: 0.1265 Acc: 0.9530
# Val Loss: 0.1655 Acc: 0.9390
#
# Epoch 50/199
# ----------
# Train Loss: 0.1188 Acc: 0.9535
# Val Loss: 0.1525 Acc: 0.9480
#
# Epoch 51/199
# ----------
# Train Loss: 0.1183 Acc: 0.9550
# Val Loss: 0.1848 Acc: 0.9410
#
# Epoch 52/199
# ----------
# Train Loss: 0.1438 Acc: 0.9475
# Val Loss: 0.1899 Acc: 0.9310
#
# Epoch 53/199
# ----------
# Train Loss: 0.1087 Acc: 0.9573
# Val Loss: 0.1793 Acc: 0.9320
#
# Epoch 54/199
# ----------
# Train Loss: 0.1240 Acc: 0.9525
# Val Loss: 0.2127 Acc: 0.9210
#
# Epoch 55/199
# ----------
# Train Loss: 0.1298 Acc: 0.9525
# Val Loss: 0.1744 Acc: 0.9400
#
# Epoch 56/199
# ----------
# Train Loss: 0.1071 Acc: 0.9617
# Val Loss: 0.1625 Acc: 0.9400
#
# Epoch 57/199
# ----------
# Train Loss: 0.1642 Acc: 0.9507
# Val Loss: 0.2489 Acc: 0.9140
#
# Epoch 58/199
# ----------
# Train Loss: 0.1326 Acc: 0.9537
# Val Loss: 0.1497 Acc: 0.9370
#
# Epoch 59/199
# ----------
# Train Loss: 0.1006 Acc: 0.9625
# Val Loss: 0.1682 Acc: 0.9370
#
# Epoch 60/199
# ----------
# Train Loss: 0.1013 Acc: 0.9593
# Val Loss: 0.2891 Acc: 0.9010
#
# Epoch 61/199
# ----------
# Train Loss: 0.1370 Acc: 0.9503
# Val Loss: 0.1999 Acc: 0.9280
#
# Epoch 62/199
# ----------
# Train Loss: 0.0918 Acc: 0.9617
# Val Loss: 0.2056 Acc: 0.9340
#
# Epoch 63/199
# ----------
# Train Loss: 0.0945 Acc: 0.9643
# Val Loss: 0.1809 Acc: 0.9340
#
# Epoch 64/199
# ----------
# Train Loss: 0.1094 Acc: 0.9590
# Val Loss: 0.3476 Acc: 0.8720
#
# Epoch 65/199
# ----------
# Train Loss: 0.1076 Acc: 0.9613
# Val Loss: 0.1673 Acc: 0.9430
#
# Epoch 66/199
# ----------
# Train Loss: 0.1025 Acc: 0.9593
# Val Loss: 0.1710 Acc: 0.9320
#
# Epoch 67/199
# ----------
# Train Loss: 0.1137 Acc: 0.9617
# Val Loss: 0.1735 Acc: 0.9470
#
# Epoch 68/199
# ----------
# Train Loss: 0.1261 Acc: 0.9595
# Val Loss: 0.1654 Acc: 0.9410
#
# Epoch 69/199
# ----------
# Train Loss: 0.0943 Acc: 0.9680
# Val Loss: 0.1765 Acc: 0.9400
#
# Epoch 70/199
# ----------
# Train Loss: 0.1230 Acc: 0.9550
# Val Loss: 0.1488 Acc: 0.9410
#
# Epoch 71/199
# ----------
# Train Loss: 0.0943 Acc: 0.9603
# Val Loss: 0.1576 Acc: 0.9430
#
# Epoch 72/199
# ----------
# Train Loss: 0.0951 Acc: 0.9625
# Val Loss: 0.1670 Acc: 0.9390
#
# Epoch 73/199
# ----------
# Train Loss: 0.0928 Acc: 0.9643
# Val Loss: 0.1729 Acc: 0.9380
#
# Epoch 74/199
# ----------
# Train Loss: 0.1032 Acc: 0.9650
# Val Loss: 0.1594 Acc: 0.9450
#
# Epoch 75/199
# ----------
# Train Loss: 0.1157 Acc: 0.9583
# Val Loss: 0.1702 Acc: 0.9290
#
# Epoch 76/199
# ----------
# Train Loss: 0.1529 Acc: 0.9517
# Val Loss: 0.1645 Acc: 0.9400
#
# Epoch 77/199
# ----------
# Train Loss: 0.0913 Acc: 0.9670
# Val Loss: 0.1831 Acc: 0.9360
#
# Epoch 78/199
# ----------
# Train Loss: 0.0934 Acc: 0.9637
# Val Loss: 0.1435 Acc: 0.9500
#
# Epoch 79/199
# ----------
# Train Loss: 0.0713 Acc: 0.9718
# Val Loss: 0.1922 Acc: 0.9430
#
# Epoch 80/199
# ----------
# Train Loss: 0.0873 Acc: 0.9673
# Val Loss: 0.1502 Acc: 0.9500
#
# Epoch 81/199
# ----------
# Train Loss: 0.0812 Acc: 0.9693
# Val Loss: 0.1528 Acc: 0.9570
#
# Epoch 82/199
# ----------
# Train Loss: 0.0837 Acc: 0.9675
# Val Loss: 0.2177 Acc: 0.9160
#
# Epoch 83/199
# ----------
# Train Loss: 0.0839 Acc: 0.9683
# Val Loss: 0.1517 Acc: 0.9530
#
# Epoch 84/199
# ----------
# Train Loss: 0.0859 Acc: 0.9677
# Val Loss: 0.3455 Acc: 0.8910
#
# Epoch 85/199
# ----------
# Train Loss: 0.1073 Acc: 0.9645
# Val Loss: 0.1481 Acc: 0.9440
#
# Epoch 86/199
# ----------
# Train Loss: 0.0890 Acc: 0.9683
# Val Loss: 0.1614 Acc: 0.9420
#
# Epoch 87/199
# ----------
# Train Loss: 0.0844 Acc: 0.9665
# Val Loss: 0.1498 Acc: 0.9490
#
# Epoch 88/199
# ----------
# Train Loss: 0.0922 Acc: 0.9673
# Val Loss: 0.1936 Acc: 0.9360
#
# Epoch 89/199
# ----------
# Train Loss: 0.0851 Acc: 0.9705
# Val Loss: 0.1809 Acc: 0.9500
#
# Epoch 90/199
# ----------
# Train Loss: 0.0711 Acc: 0.9730
# Val Loss: 0.1768 Acc: 0.9410
#
# Epoch 91/199
# ----------
# Train Loss: 0.0810 Acc: 0.9685
# Val Loss: 0.1891 Acc: 0.9400
#
# Epoch 92/199
# ----------
# Train Loss: 0.0775 Acc: 0.9715
# Val Loss: 0.1996 Acc: 0.9360
#
# Epoch 93/199
# ----------
# Train Loss: 0.0768 Acc: 0.9723
# Val Loss: 0.1483 Acc: 0.9510
#
# Epoch 94/199
# ----------
# Train Loss: 0.0659 Acc: 0.9738
# Val Loss: 0.2482 Acc: 0.9080
#
# Epoch 95/199
# ----------
# Train Loss: 0.1030 Acc: 0.9607
# Val Loss: 0.1410 Acc: 0.9520
#
# Epoch 96/199
# ----------
# Train Loss: 0.0650 Acc: 0.9753
# Val Loss: 0.1294 Acc: 0.9520
#
# Epoch 97/199
# ----------
# Train Loss: 0.0765 Acc: 0.9730
# Val Loss: 0.1951 Acc: 0.9220
#
# Epoch 98/199
# ----------
# Train Loss: 0.0650 Acc: 0.9750
# Val Loss: 0.1402 Acc: 0.9480
#
# Epoch 99/199
# ----------
# Train Loss: 0.0998 Acc: 0.9655
# Val Loss: 0.1242 Acc: 0.9540
#
# Epoch 100/199
# ----------
# Train Loss: 0.0603 Acc: 0.9755
# Val Loss: 0.1387 Acc: 0.9500
#
# Epoch 101/199
# ----------
# Train Loss: 0.0799 Acc: 0.9713
# Val Loss: 0.1689 Acc: 0.9420
#
# Epoch 102/199
# ----------
# Train Loss: 0.0589 Acc: 0.9770
# Val Loss: 0.2066 Acc: 0.9350
#
# Epoch 103/199
# ----------
# Train Loss: 0.0790 Acc: 0.9713
# Val Loss: 0.1412 Acc: 0.9400
#
# Epoch 104/199
# ----------
# Train Loss: 0.0724 Acc: 0.9735
# Val Loss: 0.1729 Acc: 0.9430
#
# Epoch 105/199
# ----------
# Train Loss: 0.0697 Acc: 0.9738
# Val Loss: 0.3297 Acc: 0.9050
#
# Epoch 106/199
# ----------
# Train Loss: 0.0695 Acc: 0.9733
# Val Loss: 0.2180 Acc: 0.9470
#
# Epoch 107/199
# ----------
# Train Loss: 0.0873 Acc: 0.9690
# Val Loss: 0.1615 Acc: 0.9490
#
# Epoch 108/199
# ----------
# Train Loss: 0.0714 Acc: 0.9720
# Val Loss: 0.1683 Acc: 0.9520
#
# Epoch 109/199
# ----------
# Train Loss: 0.0801 Acc: 0.9715
# Val Loss: 0.1568 Acc: 0.9540
#
# Epoch 110/199
# ----------
# Train Loss: 0.0511 Acc: 0.9808
# Val Loss: 0.1880 Acc: 0.9390
#
# Epoch 111/199
# ----------
# Train Loss: 0.0649 Acc: 0.9770
# Val Loss: 0.1550 Acc: 0.9500
#
# Epoch 112/199
# ----------
# Train Loss: 0.0465 Acc: 0.9830
# Val Loss: 0.1565 Acc: 0.9500
#
# Epoch 113/199
# ----------
# Train Loss: 0.0728 Acc: 0.9743
# Val Loss: 0.1992 Acc: 0.9350
#
# Epoch 114/199
# ----------
# Train Loss: 0.0561 Acc: 0.9788
# Val Loss: 0.1579 Acc: 0.9460
#
# Epoch 115/199
# ----------
# Train Loss: 0.0490 Acc: 0.9783
# Val Loss: 0.1731 Acc: 0.9430
#
# Epoch 116/199
# ----------
# Train Loss: 0.0580 Acc: 0.9798
# Val Loss: 0.1742 Acc: 0.9400
#
# Epoch 117/199
# ----------
# Train Loss: 0.0541 Acc: 0.9793
# Val Loss: 0.1915 Acc: 0.9400
#
# Epoch 118/199
# ----------
# Train Loss: 0.0690 Acc: 0.9750
# Val Loss: 0.1782 Acc: 0.9400
#
# Epoch 119/199
# ----------
# Train Loss: 0.0828 Acc: 0.9708
# Val Loss: 0.1675 Acc: 0.9510
#
# Epoch 120/199
# ----------
# Train Loss: 0.0603 Acc: 0.9795
# Val Loss: 0.1413 Acc: 0.9570
#
# Epoch 121/199
# ----------
# Train Loss: 0.0498 Acc: 0.9810
# Val Loss: 0.1601 Acc: 0.9460
#
# Epoch 122/199
# ----------
# Train Loss: 0.0484 Acc: 0.9843
# Val Loss: 0.1722 Acc: 0.9470
#
# Epoch 123/199
# ----------
# Train Loss: 0.0613 Acc: 0.9788
# Val Loss: 0.1511 Acc: 0.9590
#
# Epoch 124/199
# ----------
# Train Loss: 0.0545 Acc: 0.9785
# Val Loss: 0.1967 Acc: 0.9320
#
# Epoch 125/199
# ----------
# Train Loss: 0.0792 Acc: 0.9760
# Val Loss: 0.1860 Acc: 0.9350
#
# Epoch 126/199
# ----------
# Train Loss: 0.0694 Acc: 0.9763
# Val Loss: 0.2444 Acc: 0.9240
#
# Epoch 127/199
# ----------
# Train Loss: 0.0498 Acc: 0.9833
# Val Loss: 0.1471 Acc: 0.9580
#
# Epoch 128/199
# ----------
# Train Loss: 0.0524 Acc: 0.9813
# Val Loss: 0.1366 Acc: 0.9490
#
# Epoch 129/199
# ----------
# Train Loss: 0.0544 Acc: 0.9823
# Val Loss: 0.1662 Acc: 0.9470
#
# Epoch 130/199
# ----------
# Train Loss: 0.0497 Acc: 0.9808
# Val Loss: 0.2055 Acc: 0.9410
#
# Epoch 131/199
# ----------
# Train Loss: 0.0733 Acc: 0.9730
# Val Loss: 0.1843 Acc: 0.9400
#
# Epoch 132/199
# ----------
# Train Loss: 0.0523 Acc: 0.9800
# Val Loss: 0.1628 Acc: 0.9520
#
# Epoch 133/199
# ----------
# Train Loss: 0.0433 Acc: 0.9843
# Val Loss: 0.2011 Acc: 0.9450
#
# Epoch 134/199
# ----------
# Train Loss: 0.0632 Acc: 0.9773
# Val Loss: 0.1763 Acc: 0.9490
#
# Epoch 135/199
# ----------
# Train Loss: 0.0382 Acc: 0.9883
# Val Loss: 0.1544 Acc: 0.9510
#
# Epoch 136/199
# ----------
# Train Loss: 0.0478 Acc: 0.9840
# Val Loss: 0.1684 Acc: 0.9500
#
# Epoch 137/199
# ----------
# Train Loss: 0.0521 Acc: 0.9828
# Val Loss: 0.1782 Acc: 0.9460
#
# Epoch 138/199
# ----------
# Train Loss: 0.0592 Acc: 0.9783
# Val Loss: 0.1614 Acc: 0.9450
#
# Epoch 139/199
# ----------
# Train Loss: 0.0460 Acc: 0.9835
# Val Loss: 0.2549 Acc: 0.9330
#
# Epoch 140/199
# ----------
# Train Loss: 0.0730 Acc: 0.9753
# Val Loss: 0.1498 Acc: 0.9500
#
# Epoch 141/199
# ----------
# Train Loss: 0.0510 Acc: 0.9818
# Val Loss: 0.1536 Acc: 0.9590
#
# Epoch 142/199
# ----------
# Train Loss: 0.0403 Acc: 0.9865
# Val Loss: 0.2096 Acc: 0.9360
#
# Epoch 143/199
# ----------
# Train Loss: 0.0456 Acc: 0.9820
# Val Loss: 0.1838 Acc: 0.9540
#
# Epoch 144/199
# ----------
# Train Loss: 0.0467 Acc: 0.9808
# Val Loss: 0.2193 Acc: 0.9360
#
# Epoch 145/199
# ----------
# Train Loss: 0.0935 Acc: 0.9700
# Val Loss: 0.1936 Acc: 0.9370
#
# Epoch 146/199
# ----------
# Train Loss: 0.0448 Acc: 0.9850
# Val Loss: 0.1895 Acc: 0.9470
#
# Epoch 147/199
# ----------
# Train Loss: 0.0426 Acc: 0.9843
# Val Loss: 0.1545 Acc: 0.9530
#
# Epoch 148/199
# ----------
# Train Loss: 0.0421 Acc: 0.9848
# Val Loss: 0.1911 Acc: 0.9430
#
# Epoch 149/199
# ----------
# Train Loss: 0.0286 Acc: 0.9875
# Val Loss: 0.1653 Acc: 0.9550
#
# Epoch 150/199
# ----------
# Train Loss: 0.0546 Acc: 0.9803
# Val Loss: 0.2894 Acc: 0.9290
#
# Epoch 151/199
# ----------
# Train Loss: 0.0448 Acc: 0.9843
# Val Loss: 0.1846 Acc: 0.9550
#
# Epoch 152/199
# ----------
# Train Loss: 0.0480 Acc: 0.9820
# Val Loss: 0.1854 Acc: 0.9440
#
# Epoch 153/199
# ----------
# Train Loss: 0.0438 Acc: 0.9848
# Val Loss: 0.1910 Acc: 0.9430
#
# Epoch 154/199
# ----------
# Train Loss: 0.0467 Acc: 0.9835
# Val Loss: 0.1338 Acc: 0.9590
#
# Epoch 155/199
# ----------
# Train Loss: 0.0426 Acc: 0.9843
# Val Loss: 0.1333 Acc: 0.9630
#
# Epoch 156/199
# ----------
# Train Loss: 0.0366 Acc: 0.9880
# Val Loss: 0.1840 Acc: 0.9570
#
# Epoch 157/199
# ----------
# Train Loss: 0.0413 Acc: 0.9840
# Val Loss: 0.1693 Acc: 0.9520
#
# Epoch 158/199
# ----------
# Train Loss: 0.0325 Acc: 0.9885
# Val Loss: 0.1682 Acc: 0.9460
#
# Epoch 159/199
# ----------
# Train Loss: 0.0308 Acc: 0.9890
# Val Loss: 0.1884 Acc: 0.9430
#
# Epoch 160/199
# ----------
# Train Loss: 0.0608 Acc: 0.9815
# Val Loss: 0.2253 Acc: 0.9420
#
# Epoch 161/199
# ----------
# Train Loss: 0.0634 Acc: 0.9773
# Val Loss: 0.1912 Acc: 0.9470
#
# Epoch 162/199
# ----------
# Train Loss: 0.0317 Acc: 0.9888
# Val Loss: 0.1545 Acc: 0.9590
#
# Epoch 163/199
# ----------
# Train Loss: 0.0320 Acc: 0.9890
# Val Loss: 0.1880 Acc: 0.9480
#
# Epoch 164/199
# ----------
# Train Loss: 0.0531 Acc: 0.9858
# Val Loss: 0.1467 Acc: 0.9570
#
# Epoch 165/199
# ----------
# Train Loss: 0.0397 Acc: 0.9853
# Val Loss: 0.1611 Acc: 0.9590
#
# Epoch 166/199
# ----------
# Train Loss: 0.0452 Acc: 0.9858
# Val Loss: 0.1595 Acc: 0.9600
#
# Epoch 167/199
# ----------
# Train Loss: 0.0465 Acc: 0.9860
# Val Loss: 0.1850 Acc: 0.9480
#
# Epoch 168/199
# ----------
# Train Loss: 0.0415 Acc: 0.9858
# Val Loss: 0.1476 Acc: 0.9590
#
# Epoch 169/199
# ----------
# Train Loss: 0.0275 Acc: 0.9915
# Val Loss: 0.1510 Acc: 0.9640
#
# Epoch 170/199
# ----------
# Train Loss: 0.0351 Acc: 0.9873
# Val Loss: 0.1905 Acc: 0.9590
#
# Epoch 171/199
# ----------
# Train Loss: 0.0423 Acc: 0.9875
# Val Loss: 0.1718 Acc: 0.9600
#
# Epoch 172/199
# ----------
# Train Loss: 0.0355 Acc: 0.9890
# Val Loss: 0.1721 Acc: 0.9590
#
# Epoch 173/199
# ----------
# Train Loss: 0.0450 Acc: 0.9840
# Val Loss: 0.1805 Acc: 0.9580
#
# Epoch 174/199
# ----------
# Train Loss: 0.0331 Acc: 0.9898
# Val Loss: 0.1638 Acc: 0.9550
#
# Epoch 175/199
# ----------
# Train Loss: 0.0330 Acc: 0.9885
# Val Loss: 0.1668 Acc: 0.9590
#
# Epoch 176/199
# ----------
# Train Loss: 0.0398 Acc: 0.9885
# Val Loss: 0.1977 Acc: 0.9500
#
# Epoch 177/199
# ----------
# Train Loss: 0.0440 Acc: 0.9830
# Val Loss: 0.1543 Acc: 0.9600
#
# Epoch 178/199
# ----------
# Train Loss: 0.0357 Acc: 0.9888
# Val Loss: 0.1582 Acc: 0.9570
#
# Epoch 179/199
# ----------
# Train Loss: 0.0270 Acc: 0.9893
# Val Loss: 0.1976 Acc: 0.9510
#
# Epoch 180/199
# ----------
# Train Loss: 0.0264 Acc: 0.9915
# Val Loss: 0.2016 Acc: 0.9580
#
# Epoch 181/199
# ----------
# Train Loss: 0.0313 Acc: 0.9888
# Val Loss: 0.1783 Acc: 0.9540
#
# Epoch 182/199
# ----------
# Train Loss: 0.0442 Acc: 0.9858
# Val Loss: 0.2314 Acc: 0.9440
#
# Epoch 183/199
# ----------
# Train Loss: 0.0461 Acc: 0.9825
# Val Loss: 0.1502 Acc: 0.9570
#
# Epoch 184/199
# ----------
# Train Loss: 0.0177 Acc: 0.9942
# Val Loss: 0.1522 Acc: 0.9630
#
# Epoch 185/199
# ----------
# Train Loss: 0.0401 Acc: 0.9870
# Val Loss: 0.1503 Acc: 0.9590
#
# Epoch 186/199
# ----------
# Train Loss: 0.0414 Acc: 0.9855
# Val Loss: 0.1551 Acc: 0.9600
#
# Epoch 187/199
# ----------
# Train Loss: 0.0289 Acc: 0.9888
# Val Loss: 0.1683 Acc: 0.9560
#
# Epoch 188/199
# ----------
# Train Loss: 0.0347 Acc: 0.9883
# Val Loss: 0.2451 Acc: 0.9480
#
# Epoch 189/199
# ----------
# Train Loss: 0.0330 Acc: 0.9868
# Val Loss: 0.2211 Acc: 0.9400
#
# Epoch 190/199
# ----------
# Train Loss: 0.0663 Acc: 0.9808
# Val Loss: 0.2328 Acc: 0.9430
#
# Epoch 191/199
# ----------
# Train Loss: 0.0464 Acc: 0.9830
# Val Loss: 0.1812 Acc: 0.9430
#
# Epoch 192/199
# ----------
# Train Loss: 0.0373 Acc: 0.9890
# Val Loss: 0.2206 Acc: 0.9430
#
# Epoch 193/199
# ----------
# Train Loss: 0.0289 Acc: 0.9868
# Val Loss: 0.1633 Acc: 0.9570
#
# Epoch 194/199
# ----------
# Train Loss: 0.0288 Acc: 0.9908
# Val Loss: 0.1806 Acc: 0.9510
#
# Epoch 195/199
# ----------
# Train Loss: 0.0356 Acc: 0.9903
# Val Loss: 0.1966 Acc: 0.9480
#
# Epoch 196/199
# ----------
# Train Loss: 0.0178 Acc: 0.9940
# Val Loss: 0.2149 Acc: 0.9500
#
# Epoch 197/199
# ----------
# Train Loss: 0.0404 Acc: 0.9858
# Val Loss: 0.1724 Acc: 0.9550
#
# Epoch 198/199
# ----------
# Train Loss: 0.0191 Acc: 0.9930
# Val Loss: 0.1780 Acc: 0.9480
#
# Epoch 199/199
# ----------
# Train Loss: 0.0129 Acc: 0.9960
# Val Loss: 0.1950 Acc: 0.9620
#
# Training complete in 207m 51s
# Best val Acc: 0.964000

# %% [markdown]
# ### Figures Dataset Notebook

# %%
from cuttings import *

# %%
df_test = pd.read_csv('test/csv_padded_128/test_padded_128_final.csv',index_col=0)

# %%
# The different rock types
classes = np.array(['ML', 'MS','BL','GN','OL'])

fig, ax = plt.subplots(1,5,figsize=(10,4))

# ML rock type
ax[0].imshow(Cuttings(df_test.loc[0,'path'][:24],df_test.loc[0,'path'][24:]).load_picture(),cmap='gray')
ax[0].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft='off')
ax[0].set_yticklabels([])
ax[0].set_title(classes[df_test.loc[0,'rock_type']],fontsize=30)

# MS rock type
ax[1].imshow(Cuttings(df_test.loc[200,'path'][:24],df_test.loc[200,'path'][24:]).load_picture(),cmap='gray')
ax[1].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft='off')
ax[1].set_yticklabels([])
ax[1].set_title(classes[df_test.loc[200,'rock_type']],fontsize=30)

# BL rock type
ax[2].imshow(Cuttings(df_test.loc[400,'path'][:24],df_test.loc[400,'path'][24:]).load_picture(),cmap='gray')
ax[2].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft='off')
ax[2].set_yticklabels([])
ax[2].set_title(classes[df_test.loc[400,'rock_type']],fontsize=30)

# GN rock type
ax[3].imshow(Cuttings(df_test.loc[615,'path'][:24],df_test.loc[615,'path'][24:]).load_picture(),cmap='gray')
ax[3].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft='off')
ax[3].set_yticklabels([])
ax[3].set_title(classes[df_test.loc[615,'rock_type']],fontsize=30)

# OL rock type
ax[4].imshow(Cuttings(df_test.loc[800,'path'][:24],df_test.loc[800,'path'][24:]).load_picture(),cmap='gray')
ax[4].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft='off')
ax[4].set_yticklabels([])
ax[4].set_title(classes[df_test.loc[800,'rock_type']],fontsize=30)

# Save figure
plt.tight_layout()
plt.savefig('rock_type_problem_name.png',bbox_inches='tight')

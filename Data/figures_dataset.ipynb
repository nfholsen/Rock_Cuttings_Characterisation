# %% [markdown]
# ### Figures Dataset Notebook

# %%
from cuttings import *

# %%
date='resized_128'

# %%
df_test = pd.read_csv('test/csv/test_'+date+'_final.csv',index_col=0)

# %%
classes = np.array(['ML', 'MS','BL','GN','OL'])

# %%
fig, ax = plt.subplots(2,5,figsize=(8,4))
ax[0,0].imshow(Cuttings(df_test.loc[0,'path'][:24],df_test.loc[0,'path'][24:]).load_picture(),cmap='gray')
ax[1,0].imshow(Cuttings(df_test.loc[50,'path'][:24],df_test.loc[50,'path'][24:]).load_picture(),cmap='gray')
ax[0,0].axis('off')
ax[1,0].axis('off')
ax[0,0].title.set_text(classes[df_test.loc[0,'rock_type']])
ax[1,0].title.set_text(classes[df_test.loc[50,'rock_type']])

ax[0,1].imshow(Cuttings(df_test.loc[200,'path'][:24],df_test.loc[200,'path'][24:]).load_picture(),cmap='gray')
ax[1,1].imshow(Cuttings(df_test.loc[250,'path'][:24],df_test.loc[250,'path'][24:]).load_picture(),cmap='gray')
ax[0,1].axis('off')
ax[1,1].axis('off')
ax[0,1].title.set_text(classes[df_test.loc[200,'rock_type']])
ax[1,1].title.set_text(classes[df_test.loc[250,'rock_type']])

ax[0,2].imshow(Cuttings(df_test.loc[400,'path'][:24],df_test.loc[400,'path'][24:]).load_picture(),cmap='gray')
ax[1,2].imshow(Cuttings(df_test.loc[450,'path'][:24],df_test.loc[480,'path'][24:]).load_picture(),cmap='gray')
ax[0,2].axis('off')
ax[1,2].axis('off')
ax[0,2].title.set_text(classes[df_test.loc[400,'rock_type']])
ax[1,2].title.set_text(classes[df_test.loc[450,'rock_type']])

ax[0,3].imshow(Cuttings(df_test.loc[600,'path'][:24],df_test.loc[600,'path'][24:]).load_picture(),cmap='gray')
ax[1,3].imshow(Cuttings(df_test.loc[650,'path'][:24],df_test.loc[650,'path'][24:]).load_picture(),cmap='gray')
ax[0,3].axis('off')
ax[1,3].axis('off')
ax[0,3].title.set_text(classes[df_test.loc[600,'rock_type']])
ax[1,3].title.set_text(classes[df_test.loc[650,'rock_type']])

ax[0,4].imshow(Cuttings(df_test.loc[800,'path'][:24],df_test.loc[800,'path'][24:]).load_picture(),cmap='gray')
ax[1,4].imshow(Cuttings(df_test.loc[850,'path'][:24],df_test.loc[875,'path'][24:]).load_picture(),cmap='gray')
ax[0,4].axis('off')
ax[1,4].axis('off')
ax[0,4].title.set_text(classes[df_test.loc[800,'rock_type']])
ax[1,4].title.set_text(classes[df_test.loc[850,'rock_type']])
plt.tight_layout()
#plt.savefig('rock_type_problem_name.eps',bbox_inches='tight')
